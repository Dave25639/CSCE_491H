# %%
import os
import json
import xml.etree.ElementTree as ET
import openslide_bin
import openslide

# %%
def get_text_element(parent, path, ns):
    element = parent.find(path, ns)
    return element.text if element is not None else None

def extract_dna_methylation_filenames(dna_methylation_folder_path):
    """
    This function searches for DNA methylation files in a specified folder.
    It checks for files ending in "betas.txt" and returns a list of these filenames.

    :param dna_methylation_folder_path: Path to the folder containing the methylation data files.
    :return: A list of filenames ending with "betas.txt", or None if no such files are found.
    """
    # List to store files that end with "betas.txt"
    dna_methylation_files = []

    # Iterate through the files in the DNA methylation folder
    for filename in os.listdir(dna_methylation_folder_path):
        # Check if the file ends with "betas.txt"
        if filename.endswith("betas.txt"):
            dna_methylation_files.append(filename)

    # Return the list of files if found, otherwise None
    return dna_methylation_files if dna_methylation_files else None

def extract_clinical_data(clinical_folder_path):
    """
    This function searches for a clinical XML file within a given folder.
    It extracts relevant clinical data from the XML.
    
    :param biospecimen_folder_path: Path to the folder containing clinical data files.
    :return: JSON representation of the clinical data.
    """
    xml_file_path = None
    for filename in os.listdir(clinical_folder_path):
        if "clinical." in filename and filename.endswith(".xml"):
            xml_file_path = os.path.join(clinical_folder_path, filename)
            break

    if xml_file_path is None:
        print("No clinical XML file found.")
        return None

    tree = ET.parse(xml_file_path)
    root = tree.getroot()

    # XML namespace definition
    namespaces = {
        'coad': 'http://tcga.nci/bcr/xml/clinical/coad/2.7',
        'admin': 'http://tcga.nci/bcr/xml/administration/2.7',
        'clin_shared': 'http://tcga.nci/bcr/xml/clinical/shared/2.7',
        'shared': 'http://tcga.nci/bcr/xml/shared/2.7',
        'shared_stage': 'http://tcga.nci/bcr/xml/clinical/shared/stage/2.7',
        'coad_read_shared': 'http://tcga.nci/bcr/xml/clinical/shared/coad_read/2.7',
        'coad_nte': 'http://tcga.nci/bcr/xml/clinical/coad/shared/new_tumor_event/2.7/1.0',
        'nte': 'http://tcga.nci/bcr/xml/clinical/shared/new_tumor_event/2.7',
        'rx': 'http://tcga.nci/bcr/xml/clinical/pharmaceutical/2.7',
        'rad': 'http://tcga.nci/bcr/xml/clinical/radiation/2.7'
    }

    clinical_data = {}

    # Extract key patient data
    patient = root.find('coad:patient', namespaces)
    
    clinical_data['patient_id'] = get_text_element(patient, 'shared:patient_id', namespaces)
    clinical_data['bcr_patient_barcode'] = get_text_element(patient, 'shared:bcr_patient_barcode', namespaces)
    clinical_data['gender'] = get_text_element(patient, 'shared:gender', namespaces)
    clinical_data['tumor_tissue_site'] = get_text_element(patient, 'clin_shared:tumor_tissue_site', namespaces)
    clinical_data['days_to_birth'] = get_text_element(patient, 'clin_shared:days_to_birth', namespaces)
    clinical_data['days_to_last_followup'] = get_text_element(patient, 'clin_shared:days_to_last_followup', namespaces)
    clinical_data['days_to_death'] = get_text_element(patient, 'clin_shared:days_to_death', namespaces)
    clinical_data['histological_type'] = get_text_element(patient, 'shared:histological_type', namespaces)

    # Extract AJCC staging information
    stage_event = patient.find('shared_stage:stage_event', namespaces)
    clinical_data['ajcc_stage_version'] = get_text_element(stage_event, 'shared_stage:system_version', namespaces)
    clinical_data['pathologic_stage'] = get_text_element(stage_event, 'shared_stage:pathologic_stage', namespaces)

    # TNM categories (T, N, M)
    tnm = stage_event.find('shared_stage:tnm_categories/shared_stage:pathologic_categories', namespaces)
    clinical_data['pathologic_T'] = get_text_element(tnm, 'shared_stage:pathologic_T', namespaces)
    clinical_data['pathologic_N'] = get_text_element(tnm, 'shared_stage:pathologic_N', namespaces)
    clinical_data['pathologic_M'] = get_text_element(tnm, 'shared_stage:pathologic_M', namespaces)

    return json.dumps(clinical_data, indent=4)

def extract_biospecimen_data(biospecimen_folder_path, slide_files):
    """
    This function searches for a biospecimen CSV file and .svs image files within a given folder.
    It extracts relevant biospecimen data from the CSV and associates each sample with an .svs image if available.
    
    :param biospecimen_folder_path: Path to the folder containing biospecimen data files.
    :return: JSON representation of the biospecimen data.
    """
    biospecimen_data = []

    xml_file_path = None
    for filename in os.listdir(biospecimen_folder_path):
        if "biospecimen." in filename and filename.endswith(".xml"):
            xml_file_path = os.path.join(biospecimen_folder_path, filename)
            break

    if xml_file_path is None:
        print("No biospecimen XML file found.")
        return None
    
    # XML namespace definitions
    namespaces = {
        'bio': 'http://tcga.nci/bcr/xml/biospecimen/2.7',
        'admin': 'http://tcga.nci/bcr/xml/administration/2.7',
        'shared': 'http://tcga.nci/bcr/xml/shared/2.7'
    }

    tree = ET.parse(xml_file_path)
    root = tree.getroot()

    for sample in root.findall("bio:patient/bio:samples/bio:sample", namespaces):
        sample_data = {
            "sample_type": get_text_element(sample, 'bio:sample_type', namespaces),
            "sample_barcode": get_text_element(sample, 'bio:bcr_sample_barcode', namespaces),
            "sample_uuid": get_text_element(sample, 'bio:bcr_sample_uuid', namespaces),
            "slides": []
        }
        
        # locate portions that may contain slides
        for portion in sample.findall("bio:portions/bio:portion", namespaces):
            for slide in portion.findall("bio:slides/bio:slide", namespaces):
                slide_image_name = get_text_element(slide, 'shared:image_file_name', namespaces)

                if slide_image_name in slide_files:
                    slide_data = {
                        "slide_barcode": get_text_element(slide, 'shared:bcr_slide_barcode', namespaces),
                        "slide_uuid": get_text_element(slide, 'shared:bcr_slide_uuid', namespaces),
                        "image_file_name": get_text_element(slide, 'shared:image_file_name', namespaces),
                        "section_location": get_text_element(slide, 'bio:section_location', namespaces),
                        "percent_tumor_cells": get_text_element(slide, 'bio:percent_tumor_cells', namespaces),
                        "percent_tumor_nuclei": get_text_element(slide, 'bio:percent_tumor_nuclei', namespaces),
                        "percent_normal_cells": get_text_element(slide, 'bio:percent_normal_cells', namespaces),
                        "percent_necrosis": get_text_element(slide, 'bio:percent_necrosis', namespaces),
                        "percent_stromal_cells": get_text_element(slide, 'bio:percent_stromal_cells', namespaces),
                    }

                    slide_path = os.path.join(biospecimen_folder_path, slide_image_name)
                    try:
                        slide = openslide.OpenSlide(slide_path)
                        slide_data["resolution_level"] = slide.level_count  # Number of resolution levels
                    except Exception as e:
                        slide_data["resolution_level"] = None  # If there's an error, set to None
                        print(f"Error reading resolution for {slide_image_name}: {e}")

                    sample_data["slides"].append(slide_data)

        if sample_data["slides"]:
            biospecimen_data.append(sample_data)

    return json.dumps(biospecimen_data, indent=4)

# %%
def aggregate_case_data(cases_folder="./cases", biospecimen_folder="Biospecimen", clinical_folder="Clinical", dna_methylation_folder="DNA Methylation"):
    """
    This function iterates through each case folder in the cases folder, 
    checks for the existence of the Biospecimen, Clinical, and DNA Methylation folders, 
    and aggregates data into a JSON object.

    :param cases_folder: Path to the folder containing all case subfolders (case_001, case_002, etc.).
    :param biospecimen_folder: Folder name where Biospecimen data resides.
    :param clinical_folder: Folder name where Clinical data resides.
    :param dna_methylation_folder: Folder name where DNA Methylation data resides.
    """
    for case_id in os.listdir(cases_folder):
        case_folder = os.path.join(cases_folder, case_id)

        if os.path.isdir(case_folder):
            print(f"Processing {case_id}...")

            # initialize JSON object
            case_data = {
                "case_id": case_id,
                "biospecimen": {"has_data": False},
                "clinical": {"has_data": False},
                "methylation": {"has_data": False}
            }

            # check if DNA Methylation folder exists and extract the filenames needed
            dna_methylation_path = os.path.join(case_folder, dna_methylation_folder)
            if os.path.exists(dna_methylation_path):
                dna_methylation_filenames = extract_dna_methylation_filenames(dna_methylation_path)
                if dna_methylation_filenames:
                    case_data["methylation"]["has_data"] = True
                    case_data["methylation"]["dna_methylation_filename"] = dna_methylation_filenames
                else:
                    case_data["methylation"]["has_data"] = False
            else:
                case_data["methylation"]["has_data"] = False

            # check if Clinical folder exists and extract the data
            clinical_path = os.path.join(case_folder, clinical_folder)
            if os.path.exists(clinical_path):
                clinical_data = extract_clinical_data(clinical_path)
                if clinical_data:
                    clinical_data = json.loads(clinical_data)
                    case_data["clinical"]["has_data"] = True
                    case_data["clinical"]["clinical_patient_data"] = clinical_data
                else:
                    case_data["clinical"]["has_data"] = False
            else:
                case_data["clinical"]["has_data"] = False

            # check if Biospecimen folder exists and extract the data
            biospecimen_path = os.path.join(case_folder, biospecimen_folder)
            if os.path.exists(biospecimen_path):
                slide_files = [f for f in os.listdir(biospecimen_path) if f.endswith('.svs')] 
                if slide_files:
                    biospecimen_data = extract_biospecimen_data(biospecimen_path, slide_files)
                    if biospecimen_data:
                        biospecimen_data = json.loads(biospecimen_data)
                        case_data["biospecimen"]["has_data"] = True
                        case_data["biospecimen"]["biospecimen_data"] = biospecimen_data
                    else:
                        case_data["biospecimen"]["has_data"] = False
            else:
                case_data["biospecimen"]["has_data"] = False

            output_folder = os.path.join(case_folder, "aggregated_data")
            if not os.path.exists(output_folder):
                os.makedirs(output_folder)

            output_file = os.path.join(output_folder, f"{case_id}_data.json")
            with open(output_file, 'w') as json_file:
                json.dump(case_data, json_file, indent=4)

            print(f"Saved JSON for {case_id} in {output_file}")

import os
import json
import pandas as pd

def output_to_csv(base_dir):
    """
    Reads aggregated JSON files for each case and outputs a consolidated CSV file.

    :param base_dir: Base directory containing case folders and GENERAL_METADATA directory.
    """
    all_rows = []

    case_dirs = [d for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d))]
    general_metadata_dir = os.path.join(base_dir, "GENERAL_METADATA")
    os.makedirs(general_metadata_dir, exist_ok=True)

    if "GENERAL_METADATA" in case_dirs:
        case_dirs.remove("GENERAL_METADATA")

    for case_id in case_dirs:
        case_dir = os.path.join(base_dir, case_id, "aggregated_data")
        json_file_path = os.path.join(case_dir, f"{case_id}_data.json")

        if not os.path.exists(json_file_path):
            print(f"No aggregated JSON found for case {case_id}. Skipping...")
            continue

        with open(json_file_path, "r") as json_file:
            case_data = json.load(json_file)

        case_id = case_data.get("case_id", "Unknown")
        clinical_data = case_data.get("clinical", {}).get("clinical_patient_data", {})
        biospecimen_data = case_data.get("biospecimen", {}).get("biospecimen_data", [])
        methylation_files = case_data.get("methylation", {}).get("dna_methylation_filename", [])

        for sample in biospecimen_data:
            for slide in sample.get("slides", []):
                if(sample["sample_type"] != "Primary Tumor"):
                    continue

                row = {
                    "case_id": case_id,
                    "patient_id": clinical_data.get("patient_id"),
                    "bcr_patient_barcode": clinical_data.get("bcr_patient_barcode"),
                    "gender": clinical_data.get("gender"),
                    "tumor_tissue_site": clinical_data.get("tumor_tissue_site"),
                    "days_to_birth": clinical_data.get("days_to_birth"),
                    "days_to_last_followup": clinical_data.get("days_to_last_followup"),
                    "days_to_death": clinical_data.get("days_to_death"),
                    "histological_type": clinical_data.get("histological_type"),
                    "ajcc_stage_version": clinical_data.get("ajcc_stage_version"),
                    "pathologic_stage": clinical_data.get("pathologic_stage"),
                    "pathologic_T": clinical_data.get("pathologic_T"),
                    "pathologic_N": clinical_data.get("pathologic_N"),
                    "pathologic_M": clinical_data.get("pathologic_M"),
                    "sample_type": sample.get("sample_type"),
                    "sample_barcode": sample.get("sample_barcode"),
                    "sample_uuid": sample.get("sample_uuid"),
                    "slide_barcode": slide.get("slide_barcode"),
                    "slide_uuid": slide.get("slide_uuid"),
                    "image_file_name": slide.get("image_file_name"),
                    "section_location": slide.get("section_location"),
                    "percent_tumor_cells": slide.get("percent_tumor_cells"),
                    "percent_tumor_nuclei": slide.get("percent_tumor_nuclei"),
                    "percent_normal_cells": slide.get("percent_normal_cells"),
                    "percent_necrosis": slide.get("percent_necrosis"),
                    "percent_stromal_cells": slide.get("percent_stromal_cells"),
                    "resolution_level": slide.get("resolution_level"),
                    "embedding": slide.get("embedding"),
                    "event_occured": 1 if clinical_data.get("days_to_death") is not None else 0,
                    "dna_methylation_files": ", ".join(methylation_files)
                }
                all_rows.append(row)

    output_csv_path = os.path.join(general_metadata_dir, "consolidated_metadata.csv")
    output_parquet_path = os.path.join(general_metadata_dir, "consolidated_metadata.parquet")
    output_parquet_path_unique = os.path.join(general_metadata_dir, "consolidated_metadata_unique.parquet")
    df = pd.DataFrame(all_rows)

    #print(df.head())

    df_unique = df.drop_duplicates(subset=["case_id"], keep="first")

    print(df_unique.head())

    df_unique.to_parquet(output_parquet_path_unique, index=False)
    df.to_parquet(output_parquet_path, index=False)
    print(f"Consolidated metadata written")

# %%
aggregate_case_data("./cases") #WARNING: OVERWRITES ALL JSON METADATA
output_to_csv("./cases")
# Out:
# Processing b3c267aa-345d-40d8-a8da-f9f08c64f9c7...
# Saved JSON for b3c267aa-345d-40d8-a8da-f9f08c64f9c7 in ./cases/b3c267aa-345d-40d8-a8da-f9f08c64f9c7/aggregated_data/b3c267aa-345d-40d8-a8da-f9f08c64f9c7_data.json
# Processing a85e8208-a6f5-4e91-8f35-ef574f4273fc...
# Saved JSON for a85e8208-a6f5-4e91-8f35-ef574f4273fc in ./cases/a85e8208-a6f5-4e91-8f35-ef574f4273fc/aggregated_data/a85e8208-a6f5-4e91-8f35-ef574f4273fc_data.json
# Processing 835c3e23-ac2b-4bc9-ac65-e3e81adecf77...
# Saved JSON for 835c3e23-ac2b-4bc9-ac65-e3e81adecf77 in ./cases/835c3e23-ac2b-4bc9-ac65-e3e81adecf77/aggregated_data/835c3e23-ac2b-4bc9-ac65-e3e81adecf77_data.json
# Processing ea923671-3903-4a79-830d-e7e4b1eabab0...
# Saved JSON for ea923671-3903-4a79-830d-e7e4b1eabab0 in ./cases/ea923671-3903-4a79-830d-e7e4b1eabab0/aggregated_data/ea923671-3903-4a79-830d-e7e4b1eabab0_data.json
# Processing 131e0571-de86-415f-b3fb-dc9f971258d3...
# Saved JSON for 131e0571-de86-415f-b3fb-dc9f971258d3 in ./cases/131e0571-de86-415f-b3fb-dc9f971258d3/aggregated_data/131e0571-de86-415f-b3fb-dc9f971258d3_data.json
# Processing 1c111912-c664-42f5-9802-065b1994a2f4...
# Saved JSON for 1c111912-c664-42f5-9802-065b1994a2f4 in ./cases/1c111912-c664-42f5-9802-065b1994a2f4/aggregated_data/1c111912-c664-42f5-9802-065b1994a2f4_data.json
# Processing acd51808-870c-4684-a2de-aa0b058729e1...
# Saved JSON for acd51808-870c-4684-a2de-aa0b058729e1 in ./cases/acd51808-870c-4684-a2de-aa0b058729e1/aggregated_data/acd51808-870c-4684-a2de-aa0b058729e1_data.json
# Processing a9cb21d1-4c4a-4f30-ad4d-c54bed26f187...
# Saved JSON for a9cb21d1-4c4a-4f30-ad4d-c54bed26f187 in ./cases/a9cb21d1-4c4a-4f30-ad4d-c54bed26f187/aggregated_data/a9cb21d1-4c4a-4f30-ad4d-c54bed26f187_data.json
# Processing 912b61a1-6a5b-451c-b753-9c3dac03e8cb...
# Saved JSON for 912b61a1-6a5b-451c-b753-9c3dac03e8cb in ./cases/912b61a1-6a5b-451c-b753-9c3dac03e8cb/aggregated_data/912b61a1-6a5b-451c-b753-9c3dac03e8cb_data.json
# Processing 14efca0c-882d-4fba-b15c-64af6e213b80...
# Saved JSON for 14efca0c-882d-4fba-b15c-64af6e213b80 in ./cases/14efca0c-882d-4fba-b15c-64af6e213b80/aggregated_data/14efca0c-882d-4fba-b15c-64af6e213b80_data.json
# Processing 07dc5a1d-64b7-42ba-928e-9753bd533c1e...
# Saved JSON for 07dc5a1d-64b7-42ba-928e-9753bd533c1e in ./cases/07dc5a1d-64b7-42ba-928e-9753bd533c1e/aggregated_data/07dc5a1d-64b7-42ba-928e-9753bd533c1e_data.json
# Processing 3e1886a8-2ed2-41ee-8b58-10f5321ade6f...
# Saved JSON for 3e1886a8-2ed2-41ee-8b58-10f5321ade6f in ./cases/3e1886a8-2ed2-41ee-8b58-10f5321ade6f/aggregated_data/3e1886a8-2ed2-41ee-8b58-10f5321ade6f_data.json
# Processing cbe23011-93b7-4e9f-b934-bd0122f91f54...
# Saved JSON for cbe23011-93b7-4e9f-b934-bd0122f91f54 in ./cases/cbe23011-93b7-4e9f-b934-bd0122f91f54/aggregated_data/cbe23011-93b7-4e9f-b934-bd0122f91f54_data.json
# Processing 1136dd50-242a-4659-aad4-c53f9e759bb3...
# Saved JSON for 1136dd50-242a-4659-aad4-c53f9e759bb3 in ./cases/1136dd50-242a-4659-aad4-c53f9e759bb3/aggregated_data/1136dd50-242a-4659-aad4-c53f9e759bb3_data.json
# Processing 563d67a1-f1ba-4722-aa2d-9b35b1689468...
# Saved JSON for 563d67a1-f1ba-4722-aa2d-9b35b1689468 in ./cases/563d67a1-f1ba-4722-aa2d-9b35b1689468/aggregated_data/563d67a1-f1ba-4722-aa2d-9b35b1689468_data.json
# Processing 4f601d7b-8db1-4c6d-9374-21dcd804980d...
# Saved JSON for 4f601d7b-8db1-4c6d-9374-21dcd804980d in ./cases/4f601d7b-8db1-4c6d-9374-21dcd804980d/aggregated_data/4f601d7b-8db1-4c6d-9374-21dcd804980d_data.json
# Processing e3b0ee77-c419-4b2b-833f-90a221415489...
# Saved JSON for e3b0ee77-c419-4b2b-833f-90a221415489 in ./cases/e3b0ee77-c419-4b2b-833f-90a221415489/aggregated_data/e3b0ee77-c419-4b2b-833f-90a221415489_data.json
# Processing 622cc1c4-d721-4b5c-a88b-216d6368660b...
# Saved JSON for 622cc1c4-d721-4b5c-a88b-216d6368660b in ./cases/622cc1c4-d721-4b5c-a88b-216d6368660b/aggregated_data/622cc1c4-d721-4b5c-a88b-216d6368660b_data.json
# Processing a782f174-241d-42c6-9bc4-61cc39f8b397...
# Saved JSON for a782f174-241d-42c6-9bc4-61cc39f8b397 in ./cases/a782f174-241d-42c6-9bc4-61cc39f8b397/aggregated_data/a782f174-241d-42c6-9bc4-61cc39f8b397_data.json
# Processing 8c0894fb-5e78-40ae-be0b-329ca30f758a...
# Saved JSON for 8c0894fb-5e78-40ae-be0b-329ca30f758a in ./cases/8c0894fb-5e78-40ae-be0b-329ca30f758a/aggregated_data/8c0894fb-5e78-40ae-be0b-329ca30f758a_data.json
# Processing dc22eba5-6fb7-4875-b30a-99fa00758301...
# Saved JSON for dc22eba5-6fb7-4875-b30a-99fa00758301 in ./cases/dc22eba5-6fb7-4875-b30a-99fa00758301/aggregated_data/dc22eba5-6fb7-4875-b30a-99fa00758301_data.json
# Processing 0a815133-0edd-4422-89f2-2f067b6f2156...
# Saved JSON for 0a815133-0edd-4422-89f2-2f067b6f2156 in ./cases/0a815133-0edd-4422-89f2-2f067b6f2156/aggregated_data/0a815133-0edd-4422-89f2-2f067b6f2156_data.json
# Processing 17633a60-e12b-4a7c-bd8a-c16341ddc606...
# Saved JSON for 17633a60-e12b-4a7c-bd8a-c16341ddc606 in ./cases/17633a60-e12b-4a7c-bd8a-c16341ddc606/aggregated_data/17633a60-e12b-4a7c-bd8a-c16341ddc606_data.json
# Processing 9dcb4e16-b582-4cd0-87cf-04f480ec2cec...
# Saved JSON for 9dcb4e16-b582-4cd0-87cf-04f480ec2cec in ./cases/9dcb4e16-b582-4cd0-87cf-04f480ec2cec/aggregated_data/9dcb4e16-b582-4cd0-87cf-04f480ec2cec_data.json
# Processing 5eed7e8a-c219-4497-a99f-bfc48faca4d8...
# Saved JSON for 5eed7e8a-c219-4497-a99f-bfc48faca4d8 in ./cases/5eed7e8a-c219-4497-a99f-bfc48faca4d8/aggregated_data/5eed7e8a-c219-4497-a99f-bfc48faca4d8_data.json
# Processing 143f2dd6-a280-41c5-9242-442ef91b73ec...
# Saved JSON for 143f2dd6-a280-41c5-9242-442ef91b73ec in ./cases/143f2dd6-a280-41c5-9242-442ef91b73ec/aggregated_data/143f2dd6-a280-41c5-9242-442ef91b73ec_data.json
# Processing 7dfbc0ed-e684-4966-8b59-fb6b9e80c129...
# Saved JSON for 7dfbc0ed-e684-4966-8b59-fb6b9e80c129 in ./cases/7dfbc0ed-e684-4966-8b59-fb6b9e80c129/aggregated_data/7dfbc0ed-e684-4966-8b59-fb6b9e80c129_data.json
# Processing 8368d745-c74d-4236-ba75-16ca7aaeb3ca...
# Saved JSON for 8368d745-c74d-4236-ba75-16ca7aaeb3ca in ./cases/8368d745-c74d-4236-ba75-16ca7aaeb3ca/aggregated_data/8368d745-c74d-4236-ba75-16ca7aaeb3ca_data.json
# Processing d8e9ea52-ff28-4626-baa3-71350fd53ddf...
# Saved JSON for d8e9ea52-ff28-4626-baa3-71350fd53ddf in ./cases/d8e9ea52-ff28-4626-baa3-71350fd53ddf/aggregated_data/d8e9ea52-ff28-4626-baa3-71350fd53ddf_data.json
# Processing f38d49b7-6cad-4460-abd0-3685a3b2d941...
# Saved JSON for f38d49b7-6cad-4460-abd0-3685a3b2d941 in ./cases/f38d49b7-6cad-4460-abd0-3685a3b2d941/aggregated_data/f38d49b7-6cad-4460-abd0-3685a3b2d941_data.json
# Processing 28d03569-8717-40da-8989-70baf2b18f9f...
# Saved JSON for 28d03569-8717-40da-8989-70baf2b18f9f in ./cases/28d03569-8717-40da-8989-70baf2b18f9f/aggregated_data/28d03569-8717-40da-8989-70baf2b18f9f_data.json
# Processing 613aa3e8-a70b-45a9-9c08-0c2346c8bf00...
# Saved JSON for 613aa3e8-a70b-45a9-9c08-0c2346c8bf00 in ./cases/613aa3e8-a70b-45a9-9c08-0c2346c8bf00/aggregated_data/613aa3e8-a70b-45a9-9c08-0c2346c8bf00_data.json
# Processing a54b322b-80d3-435c-8d14-25841b741f6c...
# Saved JSON for a54b322b-80d3-435c-8d14-25841b741f6c in ./cases/a54b322b-80d3-435c-8d14-25841b741f6c/aggregated_data/a54b322b-80d3-435c-8d14-25841b741f6c_data.json
# Processing d3b7ada6-5395-4212-a921-8e97c92b605d...
# Saved JSON for d3b7ada6-5395-4212-a921-8e97c92b605d in ./cases/d3b7ada6-5395-4212-a921-8e97c92b605d/aggregated_data/d3b7ada6-5395-4212-a921-8e97c92b605d_data.json
# Processing b54865b6-824e-4163-b759-21a6eacc98ce...
# Saved JSON for b54865b6-824e-4163-b759-21a6eacc98ce in ./cases/b54865b6-824e-4163-b759-21a6eacc98ce/aggregated_data/b54865b6-824e-4163-b759-21a6eacc98ce_data.json
# Processing 1e0789d6-7efb-4807-8d36-cd9224675a0c...
# Saved JSON for 1e0789d6-7efb-4807-8d36-cd9224675a0c in ./cases/1e0789d6-7efb-4807-8d36-cd9224675a0c/aggregated_data/1e0789d6-7efb-4807-8d36-cd9224675a0c_data.json
# Processing e4be17c8-0855-432c-bb80-28bb24b62f32...
# Saved JSON for e4be17c8-0855-432c-bb80-28bb24b62f32 in ./cases/e4be17c8-0855-432c-bb80-28bb24b62f32/aggregated_data/e4be17c8-0855-432c-bb80-28bb24b62f32_data.json
# Processing 5116e3b4-2bac-40f5-8046-b9c1783faaa5...
# Saved JSON for 5116e3b4-2bac-40f5-8046-b9c1783faaa5 in ./cases/5116e3b4-2bac-40f5-8046-b9c1783faaa5/aggregated_data/5116e3b4-2bac-40f5-8046-b9c1783faaa5_data.json
# Processing 565e2726-4942-4726-89d3-c5e3797f7204...
# Saved JSON for 565e2726-4942-4726-89d3-c5e3797f7204 in ./cases/565e2726-4942-4726-89d3-c5e3797f7204/aggregated_data/565e2726-4942-4726-89d3-c5e3797f7204_data.json
# Processing 0cbe9848-8eac-4ea8-a36b-fb74b4a33de7...
# Saved JSON for 0cbe9848-8eac-4ea8-a36b-fb74b4a33de7 in ./cases/0cbe9848-8eac-4ea8-a36b-fb74b4a33de7/aggregated_data/0cbe9848-8eac-4ea8-a36b-fb74b4a33de7_data.json
# Processing c5c4a0a5-900d-483d-9282-475654d63265...
# Saved JSON for c5c4a0a5-900d-483d-9282-475654d63265 in ./cases/c5c4a0a5-900d-483d-9282-475654d63265/aggregated_data/c5c4a0a5-900d-483d-9282-475654d63265_data.json
# Processing 3334201d-a3c0-45ec-a9ed-cf48cc8c38e8...
# Saved JSON for 3334201d-a3c0-45ec-a9ed-cf48cc8c38e8 in ./cases/3334201d-a3c0-45ec-a9ed-cf48cc8c38e8/aggregated_data/3334201d-a3c0-45ec-a9ed-cf48cc8c38e8_data.json
# Processing d17a2ab0-faef-40de-a87d-1291868b200d...
# Saved JSON for d17a2ab0-faef-40de-a87d-1291868b200d in ./cases/d17a2ab0-faef-40de-a87d-1291868b200d/aggregated_data/d17a2ab0-faef-40de-a87d-1291868b200d_data.json
# Processing 32b77693-18e1-4692-8488-add1940c9e7c...
# Saved JSON for 32b77693-18e1-4692-8488-add1940c9e7c in ./cases/32b77693-18e1-4692-8488-add1940c9e7c/aggregated_data/32b77693-18e1-4692-8488-add1940c9e7c_data.json
# Processing 7a70f061-9a6f-408e-a416-7f5295ceba3b...
# Saved JSON for 7a70f061-9a6f-408e-a416-7f5295ceba3b in ./cases/7a70f061-9a6f-408e-a416-7f5295ceba3b/aggregated_data/7a70f061-9a6f-408e-a416-7f5295ceba3b_data.json
# Processing 6e9e0c2f-2ddb-40f1-8e8c-618119e62ec1...
# Saved JSON for 6e9e0c2f-2ddb-40f1-8e8c-618119e62ec1 in ./cases/6e9e0c2f-2ddb-40f1-8e8c-618119e62ec1/aggregated_data/6e9e0c2f-2ddb-40f1-8e8c-618119e62ec1_data.json
# Processing 265d7b06-65fe-42c5-ad21-e6b160e94718...
# Saved JSON for 265d7b06-65fe-42c5-ad21-e6b160e94718 in ./cases/265d7b06-65fe-42c5-ad21-e6b160e94718/aggregated_data/265d7b06-65fe-42c5-ad21-e6b160e94718_data.json
# Processing 0dc41cd5-0672-407c-9b4a-0f5f3970aa54...
# Saved JSON for 0dc41cd5-0672-407c-9b4a-0f5f3970aa54 in ./cases/0dc41cd5-0672-407c-9b4a-0f5f3970aa54/aggregated_data/0dc41cd5-0672-407c-9b4a-0f5f3970aa54_data.json
# Processing ca5b878f-8bff-410a-8e6e-b1c133018c8d...
# Saved JSON for ca5b878f-8bff-410a-8e6e-b1c133018c8d in ./cases/ca5b878f-8bff-410a-8e6e-b1c133018c8d/aggregated_data/ca5b878f-8bff-410a-8e6e-b1c133018c8d_data.json
# Processing d5a296ae-c165-413c-adcc-33c9e99ff873...
# Saved JSON for d5a296ae-c165-413c-adcc-33c9e99ff873 in ./cases/d5a296ae-c165-413c-adcc-33c9e99ff873/aggregated_data/d5a296ae-c165-413c-adcc-33c9e99ff873_data.json
# Processing c82bbe23-0264-45a7-b1a6-82b4654108c8...
# Saved JSON for c82bbe23-0264-45a7-b1a6-82b4654108c8 in ./cases/c82bbe23-0264-45a7-b1a6-82b4654108c8/aggregated_data/c82bbe23-0264-45a7-b1a6-82b4654108c8_data.json
# Processing 60ad2c8a-6bbf-43fc-ae73-cc1f6d6c163c...
# Saved JSON for 60ad2c8a-6bbf-43fc-ae73-cc1f6d6c163c in ./cases/60ad2c8a-6bbf-43fc-ae73-cc1f6d6c163c/aggregated_data/60ad2c8a-6bbf-43fc-ae73-cc1f6d6c163c_data.json
# Processing 5d73b382-3da3-4220-890e-2095228bbe6c...
# Saved JSON for 5d73b382-3da3-4220-890e-2095228bbe6c in ./cases/5d73b382-3da3-4220-890e-2095228bbe6c/aggregated_data/5d73b382-3da3-4220-890e-2095228bbe6c_data.json
# Processing da21e143-dbf6-4ac7-8872-f1d9ae39512d...
# Saved JSON for da21e143-dbf6-4ac7-8872-f1d9ae39512d in ./cases/da21e143-dbf6-4ac7-8872-f1d9ae39512d/aggregated_data/da21e143-dbf6-4ac7-8872-f1d9ae39512d_data.json
# Processing e4c0d890-a634-48bd-9108-e674532b0d2e...
# Saved JSON for e4c0d890-a634-48bd-9108-e674532b0d2e in ./cases/e4c0d890-a634-48bd-9108-e674532b0d2e/aggregated_data/e4c0d890-a634-48bd-9108-e674532b0d2e_data.json
# Processing 98d45099-feae-4dad-aa38-ec03fed6d999...
# Saved JSON for 98d45099-feae-4dad-aa38-ec03fed6d999 in ./cases/98d45099-feae-4dad-aa38-ec03fed6d999/aggregated_data/98d45099-feae-4dad-aa38-ec03fed6d999_data.json
# Processing 2c9996bb-af6e-4424-881a-e81b9c9aeb78...
# Saved JSON for 2c9996bb-af6e-4424-881a-e81b9c9aeb78 in ./cases/2c9996bb-af6e-4424-881a-e81b9c9aeb78/aggregated_data/2c9996bb-af6e-4424-881a-e81b9c9aeb78_data.json
# Processing 84e34cf2-b3bb-4a1a-8fb7-6c2c604c4008...
# Saved JSON for 84e34cf2-b3bb-4a1a-8fb7-6c2c604c4008 in ./cases/84e34cf2-b3bb-4a1a-8fb7-6c2c604c4008/aggregated_data/84e34cf2-b3bb-4a1a-8fb7-6c2c604c4008_data.json
# Processing 56e612e8-2c29-4782-be79-2813cc8dd2e6...
# Saved JSON for 56e612e8-2c29-4782-be79-2813cc8dd2e6 in ./cases/56e612e8-2c29-4782-be79-2813cc8dd2e6/aggregated_data/56e612e8-2c29-4782-be79-2813cc8dd2e6_data.json
# Processing a56f6562-d2af-47b9-bf81-94b3b4893173...
# Saved JSON for a56f6562-d2af-47b9-bf81-94b3b4893173 in ./cases/a56f6562-d2af-47b9-bf81-94b3b4893173/aggregated_data/a56f6562-d2af-47b9-bf81-94b3b4893173_data.json
# Processing 490eabca-4575-4bd6-9604-6b6e23d069ce...
# Saved JSON for 490eabca-4575-4bd6-9604-6b6e23d069ce in ./cases/490eabca-4575-4bd6-9604-6b6e23d069ce/aggregated_data/490eabca-4575-4bd6-9604-6b6e23d069ce_data.json
# Processing 86a9e44f-728e-48e4-9e1b-682b023f7c0a...
# Saved JSON for 86a9e44f-728e-48e4-9e1b-682b023f7c0a in ./cases/86a9e44f-728e-48e4-9e1b-682b023f7c0a/aggregated_data/86a9e44f-728e-48e4-9e1b-682b023f7c0a_data.json
# Processing 41f8c9fd-ae52-4458-886b-faf37de77dd0...
# Saved JSON for 41f8c9fd-ae52-4458-886b-faf37de77dd0 in ./cases/41f8c9fd-ae52-4458-886b-faf37de77dd0/aggregated_data/41f8c9fd-ae52-4458-886b-faf37de77dd0_data.json
# Processing aa85d9e8-caa6-422c-95ce-780e4ac2a5e4...
# Saved JSON for aa85d9e8-caa6-422c-95ce-780e4ac2a5e4 in ./cases/aa85d9e8-caa6-422c-95ce-780e4ac2a5e4/aggregated_data/aa85d9e8-caa6-422c-95ce-780e4ac2a5e4_data.json
# Processing a117ace8-ac5a-48d8-8aee-3024d6f0f873...
# Saved JSON for a117ace8-ac5a-48d8-8aee-3024d6f0f873 in ./cases/a117ace8-ac5a-48d8-8aee-3024d6f0f873/aggregated_data/a117ace8-ac5a-48d8-8aee-3024d6f0f873_data.json
# Processing e2edbf3f-25d8-49aa-b656-2a59c3b99aeb...
# Saved JSON for e2edbf3f-25d8-49aa-b656-2a59c3b99aeb in ./cases/e2edbf3f-25d8-49aa-b656-2a59c3b99aeb/aggregated_data/e2edbf3f-25d8-49aa-b656-2a59c3b99aeb_data.json
# Processing 127f738d-afa1-42f6-a9a0-f33806667b84...
# Saved JSON for 127f738d-afa1-42f6-a9a0-f33806667b84 in ./cases/127f738d-afa1-42f6-a9a0-f33806667b84/aggregated_data/127f738d-afa1-42f6-a9a0-f33806667b84_data.json
# Processing 5a195baa-2d05-4273-a7c4-64cc816b0406...
# Saved JSON for 5a195baa-2d05-4273-a7c4-64cc816b0406 in ./cases/5a195baa-2d05-4273-a7c4-64cc816b0406/aggregated_data/5a195baa-2d05-4273-a7c4-64cc816b0406_data.json
# Processing d42bc7f0-cfb2-4ece-ae47-521308635633...
# Saved JSON for d42bc7f0-cfb2-4ece-ae47-521308635633 in ./cases/d42bc7f0-cfb2-4ece-ae47-521308635633/aggregated_data/d42bc7f0-cfb2-4ece-ae47-521308635633_data.json
# Processing c1e141af-bdd1-4176-8c0e-cf1ab0c1d9d3...
# Saved JSON for c1e141af-bdd1-4176-8c0e-cf1ab0c1d9d3 in ./cases/c1e141af-bdd1-4176-8c0e-cf1ab0c1d9d3/aggregated_data/c1e141af-bdd1-4176-8c0e-cf1ab0c1d9d3_data.json
# Processing ebc5a6f8-34fd-48c1-a2b9-7f60f45fbf27...
# Saved JSON for ebc5a6f8-34fd-48c1-a2b9-7f60f45fbf27 in ./cases/ebc5a6f8-34fd-48c1-a2b9-7f60f45fbf27/aggregated_data/ebc5a6f8-34fd-48c1-a2b9-7f60f45fbf27_data.json
# Processing f87c6dcc-1a9e-4df5-962c-1f946e2611f8...
# Saved JSON for f87c6dcc-1a9e-4df5-962c-1f946e2611f8 in ./cases/f87c6dcc-1a9e-4df5-962c-1f946e2611f8/aggregated_data/f87c6dcc-1a9e-4df5-962c-1f946e2611f8_data.json
# Processing 384400c1-98d6-4cc3-8724-de6711f6208b...
# Saved JSON for 384400c1-98d6-4cc3-8724-de6711f6208b in ./cases/384400c1-98d6-4cc3-8724-de6711f6208b/aggregated_data/384400c1-98d6-4cc3-8724-de6711f6208b_data.json
# Processing fbb69964-f962-4b89-b59b-dd05f8faf61a...
# Saved JSON for fbb69964-f962-4b89-b59b-dd05f8faf61a in ./cases/fbb69964-f962-4b89-b59b-dd05f8faf61a/aggregated_data/fbb69964-f962-4b89-b59b-dd05f8faf61a_data.json
# Processing 268c01b3-d2ce-44c0-a2fe-ea846a1253cc...
# Saved JSON for 268c01b3-d2ce-44c0-a2fe-ea846a1253cc in ./cases/268c01b3-d2ce-44c0-a2fe-ea846a1253cc/aggregated_data/268c01b3-d2ce-44c0-a2fe-ea846a1253cc_data.json
# Processing 750770db-53cf-4021-a8c2-5e0ddb97fef5...
# Saved JSON for 750770db-53cf-4021-a8c2-5e0ddb97fef5 in ./cases/750770db-53cf-4021-a8c2-5e0ddb97fef5/aggregated_data/750770db-53cf-4021-a8c2-5e0ddb97fef5_data.json
# Processing fd16b634-2e04-44a3-862d-fb03cd73c057...
# Saved JSON for fd16b634-2e04-44a3-862d-fb03cd73c057 in ./cases/fd16b634-2e04-44a3-862d-fb03cd73c057/aggregated_data/fd16b634-2e04-44a3-862d-fb03cd73c057_data.json
# Processing 639e1050-088a-48fe-a0ef-4a01a3468cac...
# Saved JSON for 639e1050-088a-48fe-a0ef-4a01a3468cac in ./cases/639e1050-088a-48fe-a0ef-4a01a3468cac/aggregated_data/639e1050-088a-48fe-a0ef-4a01a3468cac_data.json
# Processing 81e7cca8-2d71-4446-9692-872c2fe68d0a...
# Saved JSON for 81e7cca8-2d71-4446-9692-872c2fe68d0a in ./cases/81e7cca8-2d71-4446-9692-872c2fe68d0a/aggregated_data/81e7cca8-2d71-4446-9692-872c2fe68d0a_data.json
# Processing 0712566e-3371-4715-95f1-5b792e72d758...
# Saved JSON for 0712566e-3371-4715-95f1-5b792e72d758 in ./cases/0712566e-3371-4715-95f1-5b792e72d758/aggregated_data/0712566e-3371-4715-95f1-5b792e72d758_data.json
# Processing 23d0681a-912a-408f-b19a-0bbcf5ffc2f3...
# Saved JSON for 23d0681a-912a-408f-b19a-0bbcf5ffc2f3 in ./cases/23d0681a-912a-408f-b19a-0bbcf5ffc2f3/aggregated_data/23d0681a-912a-408f-b19a-0bbcf5ffc2f3_data.json
# Processing d3062aac-4c42-41b4-a9f3-90aa72e6fb1e...
# Saved JSON for d3062aac-4c42-41b4-a9f3-90aa72e6fb1e in ./cases/d3062aac-4c42-41b4-a9f3-90aa72e6fb1e/aggregated_data/d3062aac-4c42-41b4-a9f3-90aa72e6fb1e_data.json
# Processing b76d1de7-6447-474d-bf67-77e0bb2da73a...
# Saved JSON for b76d1de7-6447-474d-bf67-77e0bb2da73a in ./cases/b76d1de7-6447-474d-bf67-77e0bb2da73a/aggregated_data/b76d1de7-6447-474d-bf67-77e0bb2da73a_data.json
# Processing aee20b98-df51-4ead-86cc-0d5f60a74b90...
# Saved JSON for aee20b98-df51-4ead-86cc-0d5f60a74b90 in ./cases/aee20b98-df51-4ead-86cc-0d5f60a74b90/aggregated_data/aee20b98-df51-4ead-86cc-0d5f60a74b90_data.json
# Processing 022f39e9-57ee-4b2b-8b3a-8929e3d69a37...
# Saved JSON for 022f39e9-57ee-4b2b-8b3a-8929e3d69a37 in ./cases/022f39e9-57ee-4b2b-8b3a-8929e3d69a37/aggregated_data/022f39e9-57ee-4b2b-8b3a-8929e3d69a37_data.json
# Processing 89a6384e-1cea-440b-9f17-d57cb0805174...
# Saved JSON for 89a6384e-1cea-440b-9f17-d57cb0805174 in ./cases/89a6384e-1cea-440b-9f17-d57cb0805174/aggregated_data/89a6384e-1cea-440b-9f17-d57cb0805174_data.json
# Processing 192da41f-f0a5-494e-8eb9-96bcdae56ff8...
# Saved JSON for 192da41f-f0a5-494e-8eb9-96bcdae56ff8 in ./cases/192da41f-f0a5-494e-8eb9-96bcdae56ff8/aggregated_data/192da41f-f0a5-494e-8eb9-96bcdae56ff8_data.json
# Processing fdffda5f-72b2-4153-b7f1-d7043b7ca898...
# Saved JSON for fdffda5f-72b2-4153-b7f1-d7043b7ca898 in ./cases/fdffda5f-72b2-4153-b7f1-d7043b7ca898/aggregated_data/fdffda5f-72b2-4153-b7f1-d7043b7ca898_data.json
# Processing cd845618-4cc4-49c2-9055-c171d4c24ee1...
# Saved JSON for cd845618-4cc4-49c2-9055-c171d4c24ee1 in ./cases/cd845618-4cc4-49c2-9055-c171d4c24ee1/aggregated_data/cd845618-4cc4-49c2-9055-c171d4c24ee1_data.json
# Processing d655bbf6-c710-411d-aff5-ceb0fb6e6680...
# Saved JSON for d655bbf6-c710-411d-aff5-ceb0fb6e6680 in ./cases/d655bbf6-c710-411d-aff5-ceb0fb6e6680/aggregated_data/d655bbf6-c710-411d-aff5-ceb0fb6e6680_data.json
# Processing 5342e2e8-1465-4f7b-9450-ef27280f80c7...
# Saved JSON for 5342e2e8-1465-4f7b-9450-ef27280f80c7 in ./cases/5342e2e8-1465-4f7b-9450-ef27280f80c7/aggregated_data/5342e2e8-1465-4f7b-9450-ef27280f80c7_data.json
# Processing 8632579e-d318-4dab-9994-d3945afc42ab...
# Saved JSON for 8632579e-d318-4dab-9994-d3945afc42ab in ./cases/8632579e-d318-4dab-9994-d3945afc42ab/aggregated_data/8632579e-d318-4dab-9994-d3945afc42ab_data.json
# Processing df5ab6cc-6f68-4b6b-95e2-954c6b57ba9c...
# Saved JSON for df5ab6cc-6f68-4b6b-95e2-954c6b57ba9c in ./cases/df5ab6cc-6f68-4b6b-95e2-954c6b57ba9c/aggregated_data/df5ab6cc-6f68-4b6b-95e2-954c6b57ba9c_data.json
# Processing 04d7a52f-a89b-4114-a608-a6254b4d604f...
# Saved JSON for 04d7a52f-a89b-4114-a608-a6254b4d604f in ./cases/04d7a52f-a89b-4114-a608-a6254b4d604f/aggregated_data/04d7a52f-a89b-4114-a608-a6254b4d604f_data.json
# Processing e394e9ec-7288-4ede-9ef8-41b631d100dd...
# Saved JSON for e394e9ec-7288-4ede-9ef8-41b631d100dd in ./cases/e394e9ec-7288-4ede-9ef8-41b631d100dd/aggregated_data/e394e9ec-7288-4ede-9ef8-41b631d100dd_data.json
# Processing 7b47489f-c3cc-4388-b5d7-c7c02790a5f6...
# Saved JSON for 7b47489f-c3cc-4388-b5d7-c7c02790a5f6 in ./cases/7b47489f-c3cc-4388-b5d7-c7c02790a5f6/aggregated_data/7b47489f-c3cc-4388-b5d7-c7c02790a5f6_data.json
# Processing aec0c661-afac-4f7a-8c31-154d743f2499...
# Saved JSON for aec0c661-afac-4f7a-8c31-154d743f2499 in ./cases/aec0c661-afac-4f7a-8c31-154d743f2499/aggregated_data/aec0c661-afac-4f7a-8c31-154d743f2499_data.json
# Processing af17788e-a562-43aa-bd36-fd3e031f483c...
# Saved JSON for af17788e-a562-43aa-bd36-fd3e031f483c in ./cases/af17788e-a562-43aa-bd36-fd3e031f483c/aggregated_data/af17788e-a562-43aa-bd36-fd3e031f483c_data.json
# Processing 86d18004-9478-4e46-83b4-4fbe445ccb70...
# Saved JSON for 86d18004-9478-4e46-83b4-4fbe445ccb70 in ./cases/86d18004-9478-4e46-83b4-4fbe445ccb70/aggregated_data/86d18004-9478-4e46-83b4-4fbe445ccb70_data.json
# Processing c616f95f-4ea1-4019-8c17-041878085c88...
# Saved JSON for c616f95f-4ea1-4019-8c17-041878085c88 in ./cases/c616f95f-4ea1-4019-8c17-041878085c88/aggregated_data/c616f95f-4ea1-4019-8c17-041878085c88_data.json
# Processing 3a8ca50f-bc9f-4250-8c8d-22893763ea46...
# Saved JSON for 3a8ca50f-bc9f-4250-8c8d-22893763ea46 in ./cases/3a8ca50f-bc9f-4250-8c8d-22893763ea46/aggregated_data/3a8ca50f-bc9f-4250-8c8d-22893763ea46_data.json
# Processing a94e1279-a975-480a-93e9-7b1ff05cbcbf...
# Saved JSON for a94e1279-a975-480a-93e9-7b1ff05cbcbf in ./cases/a94e1279-a975-480a-93e9-7b1ff05cbcbf/aggregated_data/a94e1279-a975-480a-93e9-7b1ff05cbcbf_data.json
# Processing 2a7bbafe-d499-4241-ba3d-a52ba0a5db3c...
# Saved JSON for 2a7bbafe-d499-4241-ba3d-a52ba0a5db3c in ./cases/2a7bbafe-d499-4241-ba3d-a52ba0a5db3c/aggregated_data/2a7bbafe-d499-4241-ba3d-a52ba0a5db3c_data.json
# Processing 96e013d9-8e89-46a7-8d07-bae95af36708...
# Saved JSON for 96e013d9-8e89-46a7-8d07-bae95af36708 in ./cases/96e013d9-8e89-46a7-8d07-bae95af36708/aggregated_data/96e013d9-8e89-46a7-8d07-bae95af36708_data.json
# Processing ad440651-a2de-4bb1-90da-1e5e8975ab59...
# Saved JSON for ad440651-a2de-4bb1-90da-1e5e8975ab59 in ./cases/ad440651-a2de-4bb1-90da-1e5e8975ab59/aggregated_data/ad440651-a2de-4bb1-90da-1e5e8975ab59_data.json
# Processing 92554413-9ebc-4354-8e1b-9682f3a031d9...
# Saved JSON for 92554413-9ebc-4354-8e1b-9682f3a031d9 in ./cases/92554413-9ebc-4354-8e1b-9682f3a031d9/aggregated_data/92554413-9ebc-4354-8e1b-9682f3a031d9_data.json
# Processing 15d1b0fb-5c5f-4689-94f5-b33120a2bfae...
# Saved JSON for 15d1b0fb-5c5f-4689-94f5-b33120a2bfae in ./cases/15d1b0fb-5c5f-4689-94f5-b33120a2bfae/aggregated_data/15d1b0fb-5c5f-4689-94f5-b33120a2bfae_data.json
# Processing fb9e7684-a7f7-4f17-bc5d-1f359e1b0d42...
# Saved JSON for fb9e7684-a7f7-4f17-bc5d-1f359e1b0d42 in ./cases/fb9e7684-a7f7-4f17-bc5d-1f359e1b0d42/aggregated_data/fb9e7684-a7f7-4f17-bc5d-1f359e1b0d42_data.json
# Processing 09942e9f-c178-44bc-9cd9-f5bfa350b23f...
# Saved JSON for 09942e9f-c178-44bc-9cd9-f5bfa350b23f in ./cases/09942e9f-c178-44bc-9cd9-f5bfa350b23f/aggregated_data/09942e9f-c178-44bc-9cd9-f5bfa350b23f_data.json
# Processing 9c34830b-4d7f-4b41-9659-fbfc36c145c9...
# Saved JSON for 9c34830b-4d7f-4b41-9659-fbfc36c145c9 in ./cases/9c34830b-4d7f-4b41-9659-fbfc36c145c9/aggregated_data/9c34830b-4d7f-4b41-9659-fbfc36c145c9_data.json
# Processing 567ddc8e-2b00-417d-a326-479cb02e08dd...
# Saved JSON for 567ddc8e-2b00-417d-a326-479cb02e08dd in ./cases/567ddc8e-2b00-417d-a326-479cb02e08dd/aggregated_data/567ddc8e-2b00-417d-a326-479cb02e08dd_data.json
# Processing e17959bd-045d-4540-b43a-c3863e8ff3c0...
# Saved JSON for e17959bd-045d-4540-b43a-c3863e8ff3c0 in ./cases/e17959bd-045d-4540-b43a-c3863e8ff3c0/aggregated_data/e17959bd-045d-4540-b43a-c3863e8ff3c0_data.json
# Processing 2dced66c-1f0d-4039-a5e5-54cca77c16e9...
# Saved JSON for 2dced66c-1f0d-4039-a5e5-54cca77c16e9 in ./cases/2dced66c-1f0d-4039-a5e5-54cca77c16e9/aggregated_data/2dced66c-1f0d-4039-a5e5-54cca77c16e9_data.json
# Processing 7d8eab0a-e6c8-4449-9ebf-50c41db94a06...
# Saved JSON for 7d8eab0a-e6c8-4449-9ebf-50c41db94a06 in ./cases/7d8eab0a-e6c8-4449-9ebf-50c41db94a06/aggregated_data/7d8eab0a-e6c8-4449-9ebf-50c41db94a06_data.json
# Processing 88832340-46ad-449c-8f81-6a8e5b495510...
# Saved JSON for 88832340-46ad-449c-8f81-6a8e5b495510 in ./cases/88832340-46ad-449c-8f81-6a8e5b495510/aggregated_data/88832340-46ad-449c-8f81-6a8e5b495510_data.json
# Processing db246424-3979-4f23-b316-8d30c449ee15...
# Saved JSON for db246424-3979-4f23-b316-8d30c449ee15 in ./cases/db246424-3979-4f23-b316-8d30c449ee15/aggregated_data/db246424-3979-4f23-b316-8d30c449ee15_data.json
# Processing e8e80df9-e3ba-4dec-b8fc-a5e80d8c6798...
# Saved JSON for e8e80df9-e3ba-4dec-b8fc-a5e80d8c6798 in ./cases/e8e80df9-e3ba-4dec-b8fc-a5e80d8c6798/aggregated_data/e8e80df9-e3ba-4dec-b8fc-a5e80d8c6798_data.json
# Processing b107565b-7558-4745-952b-689178367e1c...
# Saved JSON for b107565b-7558-4745-952b-689178367e1c in ./cases/b107565b-7558-4745-952b-689178367e1c/aggregated_data/b107565b-7558-4745-952b-689178367e1c_data.json
# Processing 4ad9784e-1edc-4186-9b45-4dfe0003f74b...
# Saved JSON for 4ad9784e-1edc-4186-9b45-4dfe0003f74b in ./cases/4ad9784e-1edc-4186-9b45-4dfe0003f74b/aggregated_data/4ad9784e-1edc-4186-9b45-4dfe0003f74b_data.json
# Processing 64dcf1a5-c78c-4d3f-852c-15865b3b6189...
# Saved JSON for 64dcf1a5-c78c-4d3f-852c-15865b3b6189 in ./cases/64dcf1a5-c78c-4d3f-852c-15865b3b6189/aggregated_data/64dcf1a5-c78c-4d3f-852c-15865b3b6189_data.json
# Processing 27e2438d-bd01-4c50-9102-563276ed9922...
# Saved JSON for 27e2438d-bd01-4c50-9102-563276ed9922 in ./cases/27e2438d-bd01-4c50-9102-563276ed9922/aggregated_data/27e2438d-bd01-4c50-9102-563276ed9922_data.json
# Processing dd4be58e-da22-4bcd-bf4c-2b9e60ffda19...
# Saved JSON for dd4be58e-da22-4bcd-bf4c-2b9e60ffda19 in ./cases/dd4be58e-da22-4bcd-bf4c-2b9e60ffda19/aggregated_data/dd4be58e-da22-4bcd-bf4c-2b9e60ffda19_data.json
# Processing 6baf61b6-ae5b-42f0-adc9-0d26fda231f7...
# Saved JSON for 6baf61b6-ae5b-42f0-adc9-0d26fda231f7 in ./cases/6baf61b6-ae5b-42f0-adc9-0d26fda231f7/aggregated_data/6baf61b6-ae5b-42f0-adc9-0d26fda231f7_data.json
# Processing 65ab030d-39f2-48ab-80ac-90cb1faa823a...
# Saved JSON for 65ab030d-39f2-48ab-80ac-90cb1faa823a in ./cases/65ab030d-39f2-48ab-80ac-90cb1faa823a/aggregated_data/65ab030d-39f2-48ab-80ac-90cb1faa823a_data.json
# Processing 4a785dc7-f5f6-4607-a19d-e6354b2fb5a9...
# Saved JSON for 4a785dc7-f5f6-4607-a19d-e6354b2fb5a9 in ./cases/4a785dc7-f5f6-4607-a19d-e6354b2fb5a9/aggregated_data/4a785dc7-f5f6-4607-a19d-e6354b2fb5a9_data.json
# Processing 41658cf8-0de1-4a97-bb60-0f0107c84e00...
# Saved JSON for 41658cf8-0de1-4a97-bb60-0f0107c84e00 in ./cases/41658cf8-0de1-4a97-bb60-0f0107c84e00/aggregated_data/41658cf8-0de1-4a97-bb60-0f0107c84e00_data.json
# Processing 68801d41-535f-4b38-989b-ef4fe5f00039...
# Saved JSON for 68801d41-535f-4b38-989b-ef4fe5f00039 in ./cases/68801d41-535f-4b38-989b-ef4fe5f00039/aggregated_data/68801d41-535f-4b38-989b-ef4fe5f00039_data.json
# Processing 93cd5d07-e0d3-40f8-ae7f-beadb1efb7c1...
# Saved JSON for 93cd5d07-e0d3-40f8-ae7f-beadb1efb7c1 in ./cases/93cd5d07-e0d3-40f8-ae7f-beadb1efb7c1/aggregated_data/93cd5d07-e0d3-40f8-ae7f-beadb1efb7c1_data.json
# Processing 93ca8937-97c0-4f6e-bdec-66d32f2a7b3d...
# Saved JSON for 93ca8937-97c0-4f6e-bdec-66d32f2a7b3d in ./cases/93ca8937-97c0-4f6e-bdec-66d32f2a7b3d/aggregated_data/93ca8937-97c0-4f6e-bdec-66d32f2a7b3d_data.json
# Processing f2ef5afa-6191-43a1-a023-d53c0d985139...
# Saved JSON for f2ef5afa-6191-43a1-a023-d53c0d985139 in ./cases/f2ef5afa-6191-43a1-a023-d53c0d985139/aggregated_data/f2ef5afa-6191-43a1-a023-d53c0d985139_data.json
# Processing 269e8ca8-722d-449b-ace1-6545bd72bdd6...
# Saved JSON for 269e8ca8-722d-449b-ace1-6545bd72bdd6 in ./cases/269e8ca8-722d-449b-ace1-6545bd72bdd6/aggregated_data/269e8ca8-722d-449b-ace1-6545bd72bdd6_data.json
# Processing 02f9668c-71e6-485f-88b1-b37dc8bdd2ab...
# Saved JSON for 02f9668c-71e6-485f-88b1-b37dc8bdd2ab in ./cases/02f9668c-71e6-485f-88b1-b37dc8bdd2ab/aggregated_data/02f9668c-71e6-485f-88b1-b37dc8bdd2ab_data.json
# Processing 10994156-7c2f-420e-aeb8-11d566b3d5e4...
# Saved JSON for 10994156-7c2f-420e-aeb8-11d566b3d5e4 in ./cases/10994156-7c2f-420e-aeb8-11d566b3d5e4/aggregated_data/10994156-7c2f-420e-aeb8-11d566b3d5e4_data.json
# Processing 96ac1f4b-79b0-4517-8caf-fc05abcaaf4f...
# Saved JSON for 96ac1f4b-79b0-4517-8caf-fc05abcaaf4f in ./cases/96ac1f4b-79b0-4517-8caf-fc05abcaaf4f/aggregated_data/96ac1f4b-79b0-4517-8caf-fc05abcaaf4f_data.json
# Processing e7af286b-3dec-4cf2-8fbd-fa64b3efdf7f...
# Saved JSON for e7af286b-3dec-4cf2-8fbd-fa64b3efdf7f in ./cases/e7af286b-3dec-4cf2-8fbd-fa64b3efdf7f/aggregated_data/e7af286b-3dec-4cf2-8fbd-fa64b3efdf7f_data.json
# Processing 28033279-cc74-4775-afdf-2497f6ddb55c...
# Saved JSON for 28033279-cc74-4775-afdf-2497f6ddb55c in ./cases/28033279-cc74-4775-afdf-2497f6ddb55c/aggregated_data/28033279-cc74-4775-afdf-2497f6ddb55c_data.json
# Processing bce3ce45-4fb3-4d8e-9ec7-d24427c2ba4d...
# Saved JSON for bce3ce45-4fb3-4d8e-9ec7-d24427c2ba4d in ./cases/bce3ce45-4fb3-4d8e-9ec7-d24427c2ba4d/aggregated_data/bce3ce45-4fb3-4d8e-9ec7-d24427c2ba4d_data.json
# Processing 75c3004d-1ef4-49f9-86e0-1bb7b9553a3d...
# Saved JSON for 75c3004d-1ef4-49f9-86e0-1bb7b9553a3d in ./cases/75c3004d-1ef4-49f9-86e0-1bb7b9553a3d/aggregated_data/75c3004d-1ef4-49f9-86e0-1bb7b9553a3d_data.json
# Processing abb0d53f-f74e-45dc-8fbb-40863016f3c6...
# Saved JSON for abb0d53f-f74e-45dc-8fbb-40863016f3c6 in ./cases/abb0d53f-f74e-45dc-8fbb-40863016f3c6/aggregated_data/abb0d53f-f74e-45dc-8fbb-40863016f3c6_data.json
# Processing 9743d31a-ea8f-4847-87d2-ebf77cc5983d...
# Saved JSON for 9743d31a-ea8f-4847-87d2-ebf77cc5983d in ./cases/9743d31a-ea8f-4847-87d2-ebf77cc5983d/aggregated_data/9743d31a-ea8f-4847-87d2-ebf77cc5983d_data.json
# Processing d976782c-90c1-421d-b83c-7fc2617e2709...
# Saved JSON for d976782c-90c1-421d-b83c-7fc2617e2709 in ./cases/d976782c-90c1-421d-b83c-7fc2617e2709/aggregated_data/d976782c-90c1-421d-b83c-7fc2617e2709_data.json
# Processing 38d65618-4857-490e-86b3-0a3f772a9f60...
# Saved JSON for 38d65618-4857-490e-86b3-0a3f772a9f60 in ./cases/38d65618-4857-490e-86b3-0a3f772a9f60/aggregated_data/38d65618-4857-490e-86b3-0a3f772a9f60_data.json
# Processing a123dc45-e427-461e-8d60-c51307aa498c...
# Saved JSON for a123dc45-e427-461e-8d60-c51307aa498c in ./cases/a123dc45-e427-461e-8d60-c51307aa498c/aggregated_data/a123dc45-e427-461e-8d60-c51307aa498c_data.json
# Processing eb4e4e09-98b3-4e85-8dd2-75676ff2af14...
# Saved JSON for eb4e4e09-98b3-4e85-8dd2-75676ff2af14 in ./cases/eb4e4e09-98b3-4e85-8dd2-75676ff2af14/aggregated_data/eb4e4e09-98b3-4e85-8dd2-75676ff2af14_data.json
# Processing 19d1a5fc-3ce9-4e43-a364-a4150bcf911b...
# Saved JSON for 19d1a5fc-3ce9-4e43-a364-a4150bcf911b in ./cases/19d1a5fc-3ce9-4e43-a364-a4150bcf911b/aggregated_data/19d1a5fc-3ce9-4e43-a364-a4150bcf911b_data.json
# Processing fce1fd5a-54d2-4260-b187-4eb7035e96e9...
# Saved JSON for fce1fd5a-54d2-4260-b187-4eb7035e96e9 in ./cases/fce1fd5a-54d2-4260-b187-4eb7035e96e9/aggregated_data/fce1fd5a-54d2-4260-b187-4eb7035e96e9_data.json
# Processing 2d3ce817-b269-4662-a92d-392bd3662399...
# Saved JSON for 2d3ce817-b269-4662-a92d-392bd3662399 in ./cases/2d3ce817-b269-4662-a92d-392bd3662399/aggregated_data/2d3ce817-b269-4662-a92d-392bd3662399_data.json
# Processing a72dd578-3a6f-4807-a843-4a942500944e...
# Saved JSON for a72dd578-3a6f-4807-a843-4a942500944e in ./cases/a72dd578-3a6f-4807-a843-4a942500944e/aggregated_data/a72dd578-3a6f-4807-a843-4a942500944e_data.json
# Processing e703af88-c05f-4d7b-b225-d640e4d1a2a5...
# Saved JSON for e703af88-c05f-4d7b-b225-d640e4d1a2a5 in ./cases/e703af88-c05f-4d7b-b225-d640e4d1a2a5/aggregated_data/e703af88-c05f-4d7b-b225-d640e4d1a2a5_data.json
# Processing 85e95dda-6198-464a-9187-fd0832bebb72...
# Saved JSON for 85e95dda-6198-464a-9187-fd0832bebb72 in ./cases/85e95dda-6198-464a-9187-fd0832bebb72/aggregated_data/85e95dda-6198-464a-9187-fd0832bebb72_data.json
# Processing 57cdaa1c-4e94-4a28-ab3b-300c0457555f...
# Saved JSON for 57cdaa1c-4e94-4a28-ab3b-300c0457555f in ./cases/57cdaa1c-4e94-4a28-ab3b-300c0457555f/aggregated_data/57cdaa1c-4e94-4a28-ab3b-300c0457555f_data.json
# Processing 5f6ed48b-3b5a-4d20-8fbf-c9aa3feea186...
# Saved JSON for 5f6ed48b-3b5a-4d20-8fbf-c9aa3feea186 in ./cases/5f6ed48b-3b5a-4d20-8fbf-c9aa3feea186/aggregated_data/5f6ed48b-3b5a-4d20-8fbf-c9aa3feea186_data.json
# Processing df228c56-89ac-4122-93b3-6c0740c4ec09...
# Saved JSON for df228c56-89ac-4122-93b3-6c0740c4ec09 in ./cases/df228c56-89ac-4122-93b3-6c0740c4ec09/aggregated_data/df228c56-89ac-4122-93b3-6c0740c4ec09_data.json
# Processing 9cdca5d8-ea77-4df9-b2ba-0d5e8ec37bcd...
# Saved JSON for 9cdca5d8-ea77-4df9-b2ba-0d5e8ec37bcd in ./cases/9cdca5d8-ea77-4df9-b2ba-0d5e8ec37bcd/aggregated_data/9cdca5d8-ea77-4df9-b2ba-0d5e8ec37bcd_data.json
# Processing b3fea9bb-53f9-4ddb-922d-b570562d7a7d...
# Saved JSON for b3fea9bb-53f9-4ddb-922d-b570562d7a7d in ./cases/b3fea9bb-53f9-4ddb-922d-b570562d7a7d/aggregated_data/b3fea9bb-53f9-4ddb-922d-b570562d7a7d_data.json
# Processing 5da56982-6de7-4994-aa9e-3b01200b2959...
# Saved JSON for 5da56982-6de7-4994-aa9e-3b01200b2959 in ./cases/5da56982-6de7-4994-aa9e-3b01200b2959/aggregated_data/5da56982-6de7-4994-aa9e-3b01200b2959_data.json
# Processing 7570761b-c333-40df-ac8c-9b7f94c58ef9...
# Saved JSON for 7570761b-c333-40df-ac8c-9b7f94c58ef9 in ./cases/7570761b-c333-40df-ac8c-9b7f94c58ef9/aggregated_data/7570761b-c333-40df-ac8c-9b7f94c58ef9_data.json
# Processing beb63625-d9bf-4ccd-bc53-635b53d24240...
# Saved JSON for beb63625-d9bf-4ccd-bc53-635b53d24240 in ./cases/beb63625-d9bf-4ccd-bc53-635b53d24240/aggregated_data/beb63625-d9bf-4ccd-bc53-635b53d24240_data.json
# Processing b823d6e5-54b0-43d3-95e2-9be33dc6f734...
# Saved JSON for b823d6e5-54b0-43d3-95e2-9be33dc6f734 in ./cases/b823d6e5-54b0-43d3-95e2-9be33dc6f734/aggregated_data/b823d6e5-54b0-43d3-95e2-9be33dc6f734_data.json
# Processing 73448b56-a6c6-4c98-a153-ab704261e073...
# Saved JSON for 73448b56-a6c6-4c98-a153-ab704261e073 in ./cases/73448b56-a6c6-4c98-a153-ab704261e073/aggregated_data/73448b56-a6c6-4c98-a153-ab704261e073_data.json
# Processing 85a57cfe-f1c9-44d9-8b50-022c0d3438d1...
# Saved JSON for 85a57cfe-f1c9-44d9-8b50-022c0d3438d1 in ./cases/85a57cfe-f1c9-44d9-8b50-022c0d3438d1/aggregated_data/85a57cfe-f1c9-44d9-8b50-022c0d3438d1_data.json
# Processing 0f74d992-00da-4728-9564-086ca1b95921...
# Saved JSON for 0f74d992-00da-4728-9564-086ca1b95921 in ./cases/0f74d992-00da-4728-9564-086ca1b95921/aggregated_data/0f74d992-00da-4728-9564-086ca1b95921_data.json
# Processing 0cb0dac8-4ce2-444a-b1ae-1550e065b4d9...
# Saved JSON for 0cb0dac8-4ce2-444a-b1ae-1550e065b4d9 in ./cases/0cb0dac8-4ce2-444a-b1ae-1550e065b4d9/aggregated_data/0cb0dac8-4ce2-444a-b1ae-1550e065b4d9_data.json
# Processing fac2c617-8149-45bb-b766-fbe13dc3c425...
# Saved JSON for fac2c617-8149-45bb-b766-fbe13dc3c425 in ./cases/fac2c617-8149-45bb-b766-fbe13dc3c425/aggregated_data/fac2c617-8149-45bb-b766-fbe13dc3c425_data.json
# Processing 381cf7f3-cd7b-4660-8175-ff8062f7bf78...
# Saved JSON for 381cf7f3-cd7b-4660-8175-ff8062f7bf78 in ./cases/381cf7f3-cd7b-4660-8175-ff8062f7bf78/aggregated_data/381cf7f3-cd7b-4660-8175-ff8062f7bf78_data.json
# Processing af3a0634-4292-45bd-b948-6b6bd2d58090...
# Saved JSON for af3a0634-4292-45bd-b948-6b6bd2d58090 in ./cases/af3a0634-4292-45bd-b948-6b6bd2d58090/aggregated_data/af3a0634-4292-45bd-b948-6b6bd2d58090_data.json
# Processing 2a971e32-b0e7-4a3f-8c40-62d69c0307d8...
# Saved JSON for 2a971e32-b0e7-4a3f-8c40-62d69c0307d8 in ./cases/2a971e32-b0e7-4a3f-8c40-62d69c0307d8/aggregated_data/2a971e32-b0e7-4a3f-8c40-62d69c0307d8_data.json
# Processing e83e5700-f968-4978-bb78-56a83936ce8c...
# Saved JSON for e83e5700-f968-4978-bb78-56a83936ce8c in ./cases/e83e5700-f968-4978-bb78-56a83936ce8c/aggregated_data/e83e5700-f968-4978-bb78-56a83936ce8c_data.json
# Processing 73a142e1-8ac2-4cfe-b8cf-7e9dea64f488...
# Saved JSON for 73a142e1-8ac2-4cfe-b8cf-7e9dea64f488 in ./cases/73a142e1-8ac2-4cfe-b8cf-7e9dea64f488/aggregated_data/73a142e1-8ac2-4cfe-b8cf-7e9dea64f488_data.json
# Processing 0e87e5fd-d5bb-4c0d-952d-711a6abbf336...
# Saved JSON for 0e87e5fd-d5bb-4c0d-952d-711a6abbf336 in ./cases/0e87e5fd-d5bb-4c0d-952d-711a6abbf336/aggregated_data/0e87e5fd-d5bb-4c0d-952d-711a6abbf336_data.json
# Processing 85bdc1ac-a1a4-46c2-bc2d-e5fabf5c89e9...
# Saved JSON for 85bdc1ac-a1a4-46c2-bc2d-e5fabf5c89e9 in ./cases/85bdc1ac-a1a4-46c2-bc2d-e5fabf5c89e9/aggregated_data/85bdc1ac-a1a4-46c2-bc2d-e5fabf5c89e9_data.json
# Processing e831369c-78c0-4c75-9cf3-f46ed669312e...
# Saved JSON for e831369c-78c0-4c75-9cf3-f46ed669312e in ./cases/e831369c-78c0-4c75-9cf3-f46ed669312e/aggregated_data/e831369c-78c0-4c75-9cf3-f46ed669312e_data.json
# Processing 69fb431f-0caf-4cdd-9085-eda5b18ed15d...
# Saved JSON for 69fb431f-0caf-4cdd-9085-eda5b18ed15d in ./cases/69fb431f-0caf-4cdd-9085-eda5b18ed15d/aggregated_data/69fb431f-0caf-4cdd-9085-eda5b18ed15d_data.json
# Processing e6ec5a68-7555-4f26-bd7e-9cdb4c5f7004...
# Saved JSON for e6ec5a68-7555-4f26-bd7e-9cdb4c5f7004 in ./cases/e6ec5a68-7555-4f26-bd7e-9cdb4c5f7004/aggregated_data/e6ec5a68-7555-4f26-bd7e-9cdb4c5f7004_data.json
# Processing ce00896a-f7d2-4123-bb95-24cb6e53fc32...
# Saved JSON for ce00896a-f7d2-4123-bb95-24cb6e53fc32 in ./cases/ce00896a-f7d2-4123-bb95-24cb6e53fc32/aggregated_data/ce00896a-f7d2-4123-bb95-24cb6e53fc32_data.json
# Processing 6fc5e56a-1f5e-4ff1-948e-5ef636ebb48d...
# Saved JSON for 6fc5e56a-1f5e-4ff1-948e-5ef636ebb48d in ./cases/6fc5e56a-1f5e-4ff1-948e-5ef636ebb48d/aggregated_data/6fc5e56a-1f5e-4ff1-948e-5ef636ebb48d_data.json
# Processing 4beee9d4-ee52-4fed-bcc4-d300f5ddd4d0...
# Saved JSON for 4beee9d4-ee52-4fed-bcc4-d300f5ddd4d0 in ./cases/4beee9d4-ee52-4fed-bcc4-d300f5ddd4d0/aggregated_data/4beee9d4-ee52-4fed-bcc4-d300f5ddd4d0_data.json
# Processing 95a54459-3fac-42d5-8ec1-ed66d971d64d...
# Saved JSON for 95a54459-3fac-42d5-8ec1-ed66d971d64d in ./cases/95a54459-3fac-42d5-8ec1-ed66d971d64d/aggregated_data/95a54459-3fac-42d5-8ec1-ed66d971d64d_data.json
# Processing 4563e4e0-a661-46de-ad25-9c86a621e147...
# Saved JSON for 4563e4e0-a661-46de-ad25-9c86a621e147 in ./cases/4563e4e0-a661-46de-ad25-9c86a621e147/aggregated_data/4563e4e0-a661-46de-ad25-9c86a621e147_data.json
# Processing 74a0264d-1d31-430d-9a88-e7334c8aa96c...
# Saved JSON for 74a0264d-1d31-430d-9a88-e7334c8aa96c in ./cases/74a0264d-1d31-430d-9a88-e7334c8aa96c/aggregated_data/74a0264d-1d31-430d-9a88-e7334c8aa96c_data.json
# Processing 33e989b9-fac4-47d8-b429-269044ac772a...
# Saved JSON for 33e989b9-fac4-47d8-b429-269044ac772a in ./cases/33e989b9-fac4-47d8-b429-269044ac772a/aggregated_data/33e989b9-fac4-47d8-b429-269044ac772a_data.json
# Processing 2c0a725a-e829-4d84-89d9-d0d47f6cfa37...
# Saved JSON for 2c0a725a-e829-4d84-89d9-d0d47f6cfa37 in ./cases/2c0a725a-e829-4d84-89d9-d0d47f6cfa37/aggregated_data/2c0a725a-e829-4d84-89d9-d0d47f6cfa37_data.json
# Processing 790266bc-c252-43f4-85d1-1b06ee529cf8...
# Saved JSON for 790266bc-c252-43f4-85d1-1b06ee529cf8 in ./cases/790266bc-c252-43f4-85d1-1b06ee529cf8/aggregated_data/790266bc-c252-43f4-85d1-1b06ee529cf8_data.json
# Processing 21bdad0d-c6a2-428c-b2b4-0de282b34abc...
# Saved JSON for 21bdad0d-c6a2-428c-b2b4-0de282b34abc in ./cases/21bdad0d-c6a2-428c-b2b4-0de282b34abc/aggregated_data/21bdad0d-c6a2-428c-b2b4-0de282b34abc_data.json
# Processing eb191e71-4b6e-4c8d-8348-519be5a1e657...
# Saved JSON for eb191e71-4b6e-4c8d-8348-519be5a1e657 in ./cases/eb191e71-4b6e-4c8d-8348-519be5a1e657/aggregated_data/eb191e71-4b6e-4c8d-8348-519be5a1e657_data.json
# Processing de287a25-981d-49f8-81af-fe0300e4cd31...
# Saved JSON for de287a25-981d-49f8-81af-fe0300e4cd31 in ./cases/de287a25-981d-49f8-81af-fe0300e4cd31/aggregated_data/de287a25-981d-49f8-81af-fe0300e4cd31_data.json
# Processing 4be66108-e72a-406b-bb4b-f58ff2877336...
# Saved JSON for 4be66108-e72a-406b-bb4b-f58ff2877336 in ./cases/4be66108-e72a-406b-bb4b-f58ff2877336/aggregated_data/4be66108-e72a-406b-bb4b-f58ff2877336_data.json
# Processing d259eeb2-d15e-436d-9d37-2d0b7658bc91...
# Saved JSON for d259eeb2-d15e-436d-9d37-2d0b7658bc91 in ./cases/d259eeb2-d15e-436d-9d37-2d0b7658bc91/aggregated_data/d259eeb2-d15e-436d-9d37-2d0b7658bc91_data.json
# Processing GENERAL_METADATA...
# No clinical XML file found.
# Saved JSON for GENERAL_METADATA in ./cases/GENERAL_METADATA/aggregated_data/GENERAL_METADATA_data.json
# Processing 56eb96a4-d2c2-42fb-b26c-1a80012bcb8e...
# Saved JSON for 56eb96a4-d2c2-42fb-b26c-1a80012bcb8e in ./cases/56eb96a4-d2c2-42fb-b26c-1a80012bcb8e/aggregated_data/56eb96a4-d2c2-42fb-b26c-1a80012bcb8e_data.json
# Processing 0f008098-d8aa-46dc-8445-cca59838c582...
# Saved JSON for 0f008098-d8aa-46dc-8445-cca59838c582 in ./cases/0f008098-d8aa-46dc-8445-cca59838c582/aggregated_data/0f008098-d8aa-46dc-8445-cca59838c582_data.json
# Processing 92c043b6-8d53-4c1c-808a-c4be5e2926e6...
# Saved JSON for 92c043b6-8d53-4c1c-808a-c4be5e2926e6 in ./cases/92c043b6-8d53-4c1c-808a-c4be5e2926e6/aggregated_data/92c043b6-8d53-4c1c-808a-c4be5e2926e6_data.json
# Processing 25c3201a-3dd5-4edf-ad09-104e5c10663e...
# Saved JSON for 25c3201a-3dd5-4edf-ad09-104e5c10663e in ./cases/25c3201a-3dd5-4edf-ad09-104e5c10663e/aggregated_data/25c3201a-3dd5-4edf-ad09-104e5c10663e_data.json
# Processing 93edb105-5dc9-4a4a-9fca-c91f0161fcc7...
# Saved JSON for 93edb105-5dc9-4a4a-9fca-c91f0161fcc7 in ./cases/93edb105-5dc9-4a4a-9fca-c91f0161fcc7/aggregated_data/93edb105-5dc9-4a4a-9fca-c91f0161fcc7_data.json
# Processing d9fb85c3-ade1-47bf-8159-170f81eb130f...
# Saved JSON for d9fb85c3-ade1-47bf-8159-170f81eb130f in ./cases/d9fb85c3-ade1-47bf-8159-170f81eb130f/aggregated_data/d9fb85c3-ade1-47bf-8159-170f81eb130f_data.json
# Processing e8841edf-e070-425b-b4d4-bbb2115f9dbd...
# Saved JSON for e8841edf-e070-425b-b4d4-bbb2115f9dbd in ./cases/e8841edf-e070-425b-b4d4-bbb2115f9dbd/aggregated_data/e8841edf-e070-425b-b4d4-bbb2115f9dbd_data.json
# Processing d651f9ba-8746-46c4-852c-6c2992c7d10e...
# Saved JSON for d651f9ba-8746-46c4-852c-6c2992c7d10e in ./cases/d651f9ba-8746-46c4-852c-6c2992c7d10e/aggregated_data/d651f9ba-8746-46c4-852c-6c2992c7d10e_data.json
# Processing 99c532b0-6b42-4925-a344-fc7262c415ee...
# Saved JSON for 99c532b0-6b42-4925-a344-fc7262c415ee in ./cases/99c532b0-6b42-4925-a344-fc7262c415ee/aggregated_data/99c532b0-6b42-4925-a344-fc7262c415ee_data.json
# Processing 26a12266-c6d8-42f9-bd4e-5093d827ac9a...
# Saved JSON for 26a12266-c6d8-42f9-bd4e-5093d827ac9a in ./cases/26a12266-c6d8-42f9-bd4e-5093d827ac9a/aggregated_data/26a12266-c6d8-42f9-bd4e-5093d827ac9a_data.json
# Processing 9c45eaec-d854-4f51-80a3-2d80d6b4aebc...
# Saved JSON for 9c45eaec-d854-4f51-80a3-2d80d6b4aebc in ./cases/9c45eaec-d854-4f51-80a3-2d80d6b4aebc/aggregated_data/9c45eaec-d854-4f51-80a3-2d80d6b4aebc_data.json
# Processing a9e4b6db-8b4b-4345-a4a1-d63175eb0174...
# No clinical XML file found.
# Saved JSON for a9e4b6db-8b4b-4345-a4a1-d63175eb0174 in ./cases/a9e4b6db-8b4b-4345-a4a1-d63175eb0174/aggregated_data/a9e4b6db-8b4b-4345-a4a1-d63175eb0174_data.json
# Processing 8e87ddca-f43e-4c6f-9d5b-430b666a7f6c...
# Saved JSON for 8e87ddca-f43e-4c6f-9d5b-430b666a7f6c in ./cases/8e87ddca-f43e-4c6f-9d5b-430b666a7f6c/aggregated_data/8e87ddca-f43e-4c6f-9d5b-430b666a7f6c_data.json
# Processing 31a3877d-3e82-450e-811f-3448b06f3950...
# Saved JSON for 31a3877d-3e82-450e-811f-3448b06f3950 in ./cases/31a3877d-3e82-450e-811f-3448b06f3950/aggregated_data/31a3877d-3e82-450e-811f-3448b06f3950_data.json
# Processing 7a481097-14a3-4916-9632-d899c25fd284...
# Saved JSON for 7a481097-14a3-4916-9632-d899c25fd284 in ./cases/7a481097-14a3-4916-9632-d899c25fd284/aggregated_data/7a481097-14a3-4916-9632-d899c25fd284_data.json
# Processing eeb42912-0c7a-46bb-bd95-369b2b425727...
# Saved JSON for eeb42912-0c7a-46bb-bd95-369b2b425727 in ./cases/eeb42912-0c7a-46bb-bd95-369b2b425727/aggregated_data/eeb42912-0c7a-46bb-bd95-369b2b425727_data.json
# Processing aedde4a5-6520-40b9-9721-c9b826490b7a...
# Saved JSON for aedde4a5-6520-40b9-9721-c9b826490b7a in ./cases/aedde4a5-6520-40b9-9721-c9b826490b7a/aggregated_data/aedde4a5-6520-40b9-9721-c9b826490b7a_data.json
# Processing fafd4576-0709-49e1-926f-ad1ee09907ec...
# Saved JSON for fafd4576-0709-49e1-926f-ad1ee09907ec in ./cases/fafd4576-0709-49e1-926f-ad1ee09907ec/aggregated_data/fafd4576-0709-49e1-926f-ad1ee09907ec_data.json
# Processing 515a062e-f68e-4100-a923-bd2ce0bbe071...
# No clinical XML file found.
# Saved JSON for 515a062e-f68e-4100-a923-bd2ce0bbe071 in ./cases/515a062e-f68e-4100-a923-bd2ce0bbe071/aggregated_data/515a062e-f68e-4100-a923-bd2ce0bbe071_data.json
# Processing 7a6c54f1-f4e4-426b-b306-2ca3c4de12ca...
# Saved JSON for 7a6c54f1-f4e4-426b-b306-2ca3c4de12ca in ./cases/7a6c54f1-f4e4-426b-b306-2ca3c4de12ca/aggregated_data/7a6c54f1-f4e4-426b-b306-2ca3c4de12ca_data.json
# Processing 94067eb7-98b7-4975-bab1-c09e1b454a25...
# Saved JSON for 94067eb7-98b7-4975-bab1-c09e1b454a25 in ./cases/94067eb7-98b7-4975-bab1-c09e1b454a25/aggregated_data/94067eb7-98b7-4975-bab1-c09e1b454a25_data.json
# Processing bfb07784-693b-4c25-874e-4ad6e04a5d46...
# Saved JSON for bfb07784-693b-4c25-874e-4ad6e04a5d46 in ./cases/bfb07784-693b-4c25-874e-4ad6e04a5d46/aggregated_data/bfb07784-693b-4c25-874e-4ad6e04a5d46_data.json
# Processing 794131b8-f4be-4f15-b3b9-6f0b10a5a38b...
# Saved JSON for 794131b8-f4be-4f15-b3b9-6f0b10a5a38b in ./cases/794131b8-f4be-4f15-b3b9-6f0b10a5a38b/aggregated_data/794131b8-f4be-4f15-b3b9-6f0b10a5a38b_data.json
# Processing 80e677b1-5ebe-4069-a1a5-1538ffee6642...
# Saved JSON for 80e677b1-5ebe-4069-a1a5-1538ffee6642 in ./cases/80e677b1-5ebe-4069-a1a5-1538ffee6642/aggregated_data/80e677b1-5ebe-4069-a1a5-1538ffee6642_data.json
# Processing cbdabbcd-d8f1-4d7c-9e18-ebd83d888c51...
# Saved JSON for cbdabbcd-d8f1-4d7c-9e18-ebd83d888c51 in ./cases/cbdabbcd-d8f1-4d7c-9e18-ebd83d888c51/aggregated_data/cbdabbcd-d8f1-4d7c-9e18-ebd83d888c51_data.json
# Processing 3d8fd9b2-9aa2-4c81-8843-535ae66d6140...
# Saved JSON for 3d8fd9b2-9aa2-4c81-8843-535ae66d6140 in ./cases/3d8fd9b2-9aa2-4c81-8843-535ae66d6140/aggregated_data/3d8fd9b2-9aa2-4c81-8843-535ae66d6140_data.json
# Processing eed7405f-f8f3-41a4-a0e7-242f23087f59...
# Saved JSON for eed7405f-f8f3-41a4-a0e7-242f23087f59 in ./cases/eed7405f-f8f3-41a4-a0e7-242f23087f59/aggregated_data/eed7405f-f8f3-41a4-a0e7-242f23087f59_data.json
# Processing c6ed47f4-358b-4f06-b5cd-cdf1d5c47b43...
# Saved JSON for c6ed47f4-358b-4f06-b5cd-cdf1d5c47b43 in ./cases/c6ed47f4-358b-4f06-b5cd-cdf1d5c47b43/aggregated_data/c6ed47f4-358b-4f06-b5cd-cdf1d5c47b43_data.json
# Processing 39aec099-a33e-47a4-a602-cbf65ddd3830...
# Saved JSON for 39aec099-a33e-47a4-a602-cbf65ddd3830 in ./cases/39aec099-a33e-47a4-a602-cbf65ddd3830/aggregated_data/39aec099-a33e-47a4-a602-cbf65ddd3830_data.json
# Processing 10881458-55b2-41d1-8358-4ee6ccb8ec85...
# Saved JSON for 10881458-55b2-41d1-8358-4ee6ccb8ec85 in ./cases/10881458-55b2-41d1-8358-4ee6ccb8ec85/aggregated_data/10881458-55b2-41d1-8358-4ee6ccb8ec85_data.json
# Processing 3758f4f7-ac2f-4f9d-bee2-526196f8129a...
# Saved JSON for 3758f4f7-ac2f-4f9d-bee2-526196f8129a in ./cases/3758f4f7-ac2f-4f9d-bee2-526196f8129a/aggregated_data/3758f4f7-ac2f-4f9d-bee2-526196f8129a_data.json
# Processing 0687bea4-911a-4ef2-9fa2-531ef6ba7910...
# Saved JSON for 0687bea4-911a-4ef2-9fa2-531ef6ba7910 in ./cases/0687bea4-911a-4ef2-9fa2-531ef6ba7910/aggregated_data/0687bea4-911a-4ef2-9fa2-531ef6ba7910_data.json
# Processing 0b8de222-119a-40f3-8beb-12b9d933225b...
# Saved JSON for 0b8de222-119a-40f3-8beb-12b9d933225b in ./cases/0b8de222-119a-40f3-8beb-12b9d933225b/aggregated_data/0b8de222-119a-40f3-8beb-12b9d933225b_data.json
# Processing 2d02bd7a-5beb-4e43-9ccb-18d89c9d5ca2...
# Saved JSON for 2d02bd7a-5beb-4e43-9ccb-18d89c9d5ca2 in ./cases/2d02bd7a-5beb-4e43-9ccb-18d89c9d5ca2/aggregated_data/2d02bd7a-5beb-4e43-9ccb-18d89c9d5ca2_data.json
# Processing dde411b2-5d2b-4638-8149-89bc1eb3c7ad...
# Saved JSON for dde411b2-5d2b-4638-8149-89bc1eb3c7ad in ./cases/dde411b2-5d2b-4638-8149-89bc1eb3c7ad/aggregated_data/dde411b2-5d2b-4638-8149-89bc1eb3c7ad_data.json
# Processing c7c5348f-5708-45bf-b40e-1bf7c9348f60...
# ...
# Processing 568dbda7-88b5-4330-881f-dc5d6c7ce4ae...
# Saved JSON for 568dbda7-88b5-4330-881f-dc5d6c7ce4ae in ./cases/568dbda7-88b5-4330-881f-dc5d6c7ce4ae/aggregated_data/568dbda7-88b5-4330-881f-dc5d6c7ce4ae_data.json
# Processing 091e3084-04ee-4497-893c-d46226dec78f...
# Saved JSON for 091e3084-04ee-4497-893c-d46226dec78f in ./cases/091e3084-04ee-4497-893c-d46226dec78f/aggregated_data/091e3084-04ee-4497-893c-d46226dec78f_data.json
# Processing 3e0c34cb-fca5-4bcf-a5c1-5a7d286dd072...
# Saved JSON for 3e0c34cb-fca5-4bcf-a5c1-5a7d286dd072 in ./cases/3e0c34cb-fca5-4bcf-a5c1-5a7d286dd072/aggregated_data/3e0c34cb-fca5-4bcf-a5c1-5a7d286dd072_data.json
# Processing e457344d-76fb-46bf-b362-61a6e811d131...
# Saved JSON for e457344d-76fb-46bf-b362-61a6e811d131 in ./cases/e457344d-76fb-46bf-b362-61a6e811d131/aggregated_data/e457344d-76fb-46bf-b362-61a6e811d131_data.json
# Processing 01ad5016-f691-4bca-82a0-910429d8d25b...
# Saved JSON for 01ad5016-f691-4bca-82a0-910429d8d25b in ./cases/01ad5016-f691-4bca-82a0-910429d8d25b/aggregated_data/01ad5016-f691-4bca-82a0-910429d8d25b_data.json
# Processing 1ad0b9b9-7ded-4281-b114-9dcc6138c037...
# Saved JSON for 1ad0b9b9-7ded-4281-b114-9dcc6138c037 in ./cases/1ad0b9b9-7ded-4281-b114-9dcc6138c037/aggregated_data/1ad0b9b9-7ded-4281-b114-9dcc6138c037_data.json
# Processing ae6b315f-3f78-4695-adfa-48b0bbab2c89...
# Saved JSON for ae6b315f-3f78-4695-adfa-48b0bbab2c89 in ./cases/ae6b315f-3f78-4695-adfa-48b0bbab2c89/aggregated_data/ae6b315f-3f78-4695-adfa-48b0bbab2c89_data.json
# Processing 77a44132-af22-4115-9fa2-78f2f74bf687...
# Saved JSON for 77a44132-af22-4115-9fa2-78f2f74bf687 in ./cases/77a44132-af22-4115-9fa2-78f2f74bf687/aggregated_data/77a44132-af22-4115-9fa2-78f2f74bf687_data.json
# Processing c594196e-49ef-4195-a6b6-4ef4a1d9ec15...
# Saved JSON for c594196e-49ef-4195-a6b6-4ef4a1d9ec15 in ./cases/c594196e-49ef-4195-a6b6-4ef4a1d9ec15/aggregated_data/c594196e-49ef-4195-a6b6-4ef4a1d9ec15_data.json
# Processing d4e1472a-7b5f-46f4-acb7-b961f634e28e...
# Saved JSON for d4e1472a-7b5f-46f4-acb7-b961f634e28e in ./cases/d4e1472a-7b5f-46f4-acb7-b961f634e28e/aggregated_data/d4e1472a-7b5f-46f4-acb7-b961f634e28e_data.json
# Processing 7f6898e2-a840-4ad1-80f7-783f8b766fcc...
# Saved JSON for 7f6898e2-a840-4ad1-80f7-783f8b766fcc in ./cases/7f6898e2-a840-4ad1-80f7-783f8b766fcc/aggregated_data/7f6898e2-a840-4ad1-80f7-783f8b766fcc_data.json
# Processing b728e6e8-a0e4-496b-904c-6f07c12e901f...
# Saved JSON for b728e6e8-a0e4-496b-904c-6f07c12e901f in ./cases/b728e6e8-a0e4-496b-904c-6f07c12e901f/aggregated_data/b728e6e8-a0e4-496b-904c-6f07c12e901f_data.json
# Processing 35c9264f-34ec-4d75-ab80-aaac86108fc8...
# Saved JSON for 35c9264f-34ec-4d75-ab80-aaac86108fc8 in ./cases/35c9264f-34ec-4d75-ab80-aaac86108fc8/aggregated_data/35c9264f-34ec-4d75-ab80-aaac86108fc8_data.json
# Processing 80311cf5-7e18-4545-92ad-c4b7dd5c9677...
# Saved JSON for 80311cf5-7e18-4545-92ad-c4b7dd5c9677 in ./cases/80311cf5-7e18-4545-92ad-c4b7dd5c9677/aggregated_data/80311cf5-7e18-4545-92ad-c4b7dd5c9677_data.json
# Processing 03efbc94-a43d-4db0-9377-e397348430a6...
# Saved JSON for 03efbc94-a43d-4db0-9377-e397348430a6 in ./cases/03efbc94-a43d-4db0-9377-e397348430a6/aggregated_data/03efbc94-a43d-4db0-9377-e397348430a6_data.json
# Processing c8d6fe73-3504-42a5-9723-e1916fba8208...
# Saved JSON for c8d6fe73-3504-42a5-9723-e1916fba8208 in ./cases/c8d6fe73-3504-42a5-9723-e1916fba8208/aggregated_data/c8d6fe73-3504-42a5-9723-e1916fba8208_data.json
# Processing 13eff2e5-e33a-485f-9ba4-8a7ccb3c7528...
# Saved JSON for 13eff2e5-e33a-485f-9ba4-8a7ccb3c7528 in ./cases/13eff2e5-e33a-485f-9ba4-8a7ccb3c7528/aggregated_data/13eff2e5-e33a-485f-9ba4-8a7ccb3c7528_data.json
# Processing 7144a65f-a63f-4b79-8fe2-cfe48696de03...
# Saved JSON for 7144a65f-a63f-4b79-8fe2-cfe48696de03 in ./cases/7144a65f-a63f-4b79-8fe2-cfe48696de03/aggregated_data/7144a65f-a63f-4b79-8fe2-cfe48696de03_data.json
# Processing 57b0f89f-1b75-453e-922c-01cd4d44ca49...
# Saved JSON for 57b0f89f-1b75-453e-922c-01cd4d44ca49 in ./cases/57b0f89f-1b75-453e-922c-01cd4d44ca49/aggregated_data/57b0f89f-1b75-453e-922c-01cd4d44ca49_data.json
# Processing c777a777-373a-4773-9566-6c373261f00a...
# Saved JSON for c777a777-373a-4773-9566-6c373261f00a in ./cases/c777a777-373a-4773-9566-6c373261f00a/aggregated_data/c777a777-373a-4773-9566-6c373261f00a_data.json
# Processing 14cc6f5b-5692-471e-98b4-ae200b3d8fed...
# Saved JSON for 14cc6f5b-5692-471e-98b4-ae200b3d8fed in ./cases/14cc6f5b-5692-471e-98b4-ae200b3d8fed/aggregated_data/14cc6f5b-5692-471e-98b4-ae200b3d8fed_data.json
# Processing 5c24435e-8e50-42c2-80c7-919b1cad0133...
# Saved JSON for 5c24435e-8e50-42c2-80c7-919b1cad0133 in ./cases/5c24435e-8e50-42c2-80c7-919b1cad0133/aggregated_data/5c24435e-8e50-42c2-80c7-919b1cad0133_data.json
# Processing 79d33c28-a7e2-4fca-8be1-a16fb6d68d49...
# Saved JSON for 79d33c28-a7e2-4fca-8be1-a16fb6d68d49 in ./cases/79d33c28-a7e2-4fca-8be1-a16fb6d68d49/aggregated_data/79d33c28-a7e2-4fca-8be1-a16fb6d68d49_data.json
# Processing 93690a96-421c-4c59-85ba-fa6dd538c721...
# Saved JSON for 93690a96-421c-4c59-85ba-fa6dd538c721 in ./cases/93690a96-421c-4c59-85ba-fa6dd538c721/aggregated_data/93690a96-421c-4c59-85ba-fa6dd538c721_data.json
# Processing d7ebd11a-1339-4b28-be90-a788d2cfa706...
# Saved JSON for d7ebd11a-1339-4b28-be90-a788d2cfa706 in ./cases/d7ebd11a-1339-4b28-be90-a788d2cfa706/aggregated_data/d7ebd11a-1339-4b28-be90-a788d2cfa706_data.json
# Processing cc22913d-2dda-48bb-82aa-9960b73f3e44...
# Saved JSON for cc22913d-2dda-48bb-82aa-9960b73f3e44 in ./cases/cc22913d-2dda-48bb-82aa-9960b73f3e44/aggregated_data/cc22913d-2dda-48bb-82aa-9960b73f3e44_data.json
# Processing d181c72b-843c-4b2d-b014-2a6dd1c3c1ec...
# Saved JSON for d181c72b-843c-4b2d-b014-2a6dd1c3c1ec in ./cases/d181c72b-843c-4b2d-b014-2a6dd1c3c1ec/aggregated_data/d181c72b-843c-4b2d-b014-2a6dd1c3c1ec_data.json
# Processing 97f6c8d3-09a0-4128-8f10-41e736648a5f...
# Saved JSON for 97f6c8d3-09a0-4128-8f10-41e736648a5f in ./cases/97f6c8d3-09a0-4128-8f10-41e736648a5f/aggregated_data/97f6c8d3-09a0-4128-8f10-41e736648a5f_data.json
# Processing ef4bb5bf-4535-4bd1-8a74-aba920123ee2...
# Saved JSON for ef4bb5bf-4535-4bd1-8a74-aba920123ee2 in ./cases/ef4bb5bf-4535-4bd1-8a74-aba920123ee2/aggregated_data/ef4bb5bf-4535-4bd1-8a74-aba920123ee2_data.json
# Processing dca004bf-9c14-45a1-b186-ab3759f6c7fe...
# Saved JSON for dca004bf-9c14-45a1-b186-ab3759f6c7fe in ./cases/dca004bf-9c14-45a1-b186-ab3759f6c7fe/aggregated_data/dca004bf-9c14-45a1-b186-ab3759f6c7fe_data.json
# Processing fa83dfb5-7386-4a35-9861-aa866478d5f1...
# Saved JSON for fa83dfb5-7386-4a35-9861-aa866478d5f1 in ./cases/fa83dfb5-7386-4a35-9861-aa866478d5f1/aggregated_data/fa83dfb5-7386-4a35-9861-aa866478d5f1_data.json
# Processing c46971a1-cbac-425d-bac2-f4142c92522e...
# Saved JSON for c46971a1-cbac-425d-bac2-f4142c92522e in ./cases/c46971a1-cbac-425d-bac2-f4142c92522e/aggregated_data/c46971a1-cbac-425d-bac2-f4142c92522e_data.json
# Processing e75985cb-357e-4072-b047-eea37965d70c...
# Saved JSON for e75985cb-357e-4072-b047-eea37965d70c in ./cases/e75985cb-357e-4072-b047-eea37965d70c/aggregated_data/e75985cb-357e-4072-b047-eea37965d70c_data.json
# Processing 733d8b6a-ca9d-4a69-8c9c-1f88733e8b68...
# Saved JSON for 733d8b6a-ca9d-4a69-8c9c-1f88733e8b68 in ./cases/733d8b6a-ca9d-4a69-8c9c-1f88733e8b68/aggregated_data/733d8b6a-ca9d-4a69-8c9c-1f88733e8b68_data.json
# Processing 47a8e514-904c-4867-8f43-7eb573be835b...
# Saved JSON for 47a8e514-904c-4867-8f43-7eb573be835b in ./cases/47a8e514-904c-4867-8f43-7eb573be835b/aggregated_data/47a8e514-904c-4867-8f43-7eb573be835b_data.json
# Processing 39d3b5b3-d51e-4d77-a8aa-2977fa734fab...
# Saved JSON for 39d3b5b3-d51e-4d77-a8aa-2977fa734fab in ./cases/39d3b5b3-d51e-4d77-a8aa-2977fa734fab/aggregated_data/39d3b5b3-d51e-4d77-a8aa-2977fa734fab_data.json
# Processing 6f2b5a14-569c-4084-8c67-b1a44d787897...
# Saved JSON for 6f2b5a14-569c-4084-8c67-b1a44d787897 in ./cases/6f2b5a14-569c-4084-8c67-b1a44d787897/aggregated_data/6f2b5a14-569c-4084-8c67-b1a44d787897_data.json
# Processing a8b4284d-cbbb-43e3-897b-d04af4bfba74...
# Saved JSON for a8b4284d-cbbb-43e3-897b-d04af4bfba74 in ./cases/a8b4284d-cbbb-43e3-897b-d04af4bfba74/aggregated_data/a8b4284d-cbbb-43e3-897b-d04af4bfba74_data.json
# Processing 49929108-023e-4d35-b26d-50ab4d3ae581...
# Saved JSON for 49929108-023e-4d35-b26d-50ab4d3ae581 in ./cases/49929108-023e-4d35-b26d-50ab4d3ae581/aggregated_data/49929108-023e-4d35-b26d-50ab4d3ae581_data.json
# Processing 857a5889-19e7-4208-8362-f1377c408037...
# Saved JSON for 857a5889-19e7-4208-8362-f1377c408037 in ./cases/857a5889-19e7-4208-8362-f1377c408037/aggregated_data/857a5889-19e7-4208-8362-f1377c408037_data.json
# Processing 132229e5-947d-43e9-a54c-a97d4be7d604...
# Saved JSON for 132229e5-947d-43e9-a54c-a97d4be7d604 in ./cases/132229e5-947d-43e9-a54c-a97d4be7d604/aggregated_data/132229e5-947d-43e9-a54c-a97d4be7d604_data.json
# Processing f1e6ce83-b4a0-4643-8e8e-a1ef8a158a27...
# Saved JSON for f1e6ce83-b4a0-4643-8e8e-a1ef8a158a27 in ./cases/f1e6ce83-b4a0-4643-8e8e-a1ef8a158a27/aggregated_data/f1e6ce83-b4a0-4643-8e8e-a1ef8a158a27_data.json
# Processing e5921d6b-51cf-44be-b295-610cf7c3a69a...
# Saved JSON for e5921d6b-51cf-44be-b295-610cf7c3a69a in ./cases/e5921d6b-51cf-44be-b295-610cf7c3a69a/aggregated_data/e5921d6b-51cf-44be-b295-610cf7c3a69a_data.json
# Processing b89267a4-0e6b-401e-85b0-e66775858aa6...
# Saved JSON for b89267a4-0e6b-401e-85b0-e66775858aa6 in ./cases/b89267a4-0e6b-401e-85b0-e66775858aa6/aggregated_data/b89267a4-0e6b-401e-85b0-e66775858aa6_data.json
# Processing 01240896-3f3f-4bf9-9799-55c87bfacf36...
# Saved JSON for 01240896-3f3f-4bf9-9799-55c87bfacf36 in ./cases/01240896-3f3f-4bf9-9799-55c87bfacf36/aggregated_data/01240896-3f3f-4bf9-9799-55c87bfacf36_data.json
# Processing 64b0461f-038d-4712-948e-818dc2f10eef...
# Saved JSON for 64b0461f-038d-4712-948e-818dc2f10eef in ./cases/64b0461f-038d-4712-948e-818dc2f10eef/aggregated_data/64b0461f-038d-4712-948e-818dc2f10eef_data.json
# Processing ac6a3df9-41b1-4e5a-a15e-f44481384c23...
# Saved JSON for ac6a3df9-41b1-4e5a-a15e-f44481384c23 in ./cases/ac6a3df9-41b1-4e5a-a15e-f44481384c23/aggregated_data/ac6a3df9-41b1-4e5a-a15e-f44481384c23_data.json
# Processing c293a148-a88c-4fb3-b2f4-e64e918044f9...
# Saved JSON for c293a148-a88c-4fb3-b2f4-e64e918044f9 in ./cases/c293a148-a88c-4fb3-b2f4-e64e918044f9/aggregated_data/c293a148-a88c-4fb3-b2f4-e64e918044f9_data.json
# Processing 33522271-b2ca-4da4-a942-501ab9117c51...
# Saved JSON for 33522271-b2ca-4da4-a942-501ab9117c51 in ./cases/33522271-b2ca-4da4-a942-501ab9117c51/aggregated_data/33522271-b2ca-4da4-a942-501ab9117c51_data.json
# Processing 39b6ae01-c97b-4234-8a28-208fdf170432...
# Saved JSON for 39b6ae01-c97b-4234-8a28-208fdf170432 in ./cases/39b6ae01-c97b-4234-8a28-208fdf170432/aggregated_data/39b6ae01-c97b-4234-8a28-208fdf170432_data.json
# Processing 5b259d18-3976-4f44-967f-fe5fa8447c8b...
# Saved JSON for 5b259d18-3976-4f44-967f-fe5fa8447c8b in ./cases/5b259d18-3976-4f44-967f-fe5fa8447c8b/aggregated_data/5b259d18-3976-4f44-967f-fe5fa8447c8b_data.json
# Processing 755d3bde-76c3-45c1-8427-8e4d5d686dc1...
# Saved JSON for 755d3bde-76c3-45c1-8427-8e4d5d686dc1 in ./cases/755d3bde-76c3-45c1-8427-8e4d5d686dc1/aggregated_data/755d3bde-76c3-45c1-8427-8e4d5d686dc1_data.json
# Processing 23252dca-e836-47a0-b294-758ad60aa259...
# Saved JSON for 23252dca-e836-47a0-b294-758ad60aa259 in ./cases/23252dca-e836-47a0-b294-758ad60aa259/aggregated_data/23252dca-e836-47a0-b294-758ad60aa259_data.json
# Processing a435fdf4-a89a-499e-9006-cbb5693eab26...
# Saved JSON for a435fdf4-a89a-499e-9006-cbb5693eab26 in ./cases/a435fdf4-a89a-499e-9006-cbb5693eab26/aggregated_data/a435fdf4-a89a-499e-9006-cbb5693eab26_data.json
# Processing d5619045-060a-4b60-86e4-6a5774994fd4...
# Saved JSON for d5619045-060a-4b60-86e4-6a5774994fd4 in ./cases/d5619045-060a-4b60-86e4-6a5774994fd4/aggregated_data/d5619045-060a-4b60-86e4-6a5774994fd4_data.json
# Processing b4c3cf95-a27c-4bcf-9321-38723473e83b...
# Saved JSON for b4c3cf95-a27c-4bcf-9321-38723473e83b in ./cases/b4c3cf95-a27c-4bcf-9321-38723473e83b/aggregated_data/b4c3cf95-a27c-4bcf-9321-38723473e83b_data.json
# Processing c085da47-d634-491a-80ea-514e5a231f70...
# Saved JSON for c085da47-d634-491a-80ea-514e5a231f70 in ./cases/c085da47-d634-491a-80ea-514e5a231f70/aggregated_data/c085da47-d634-491a-80ea-514e5a231f70_data.json
# Processing ec3f3f11-75df-4fcc-ba03-f19aca907645...
# Saved JSON for ec3f3f11-75df-4fcc-ba03-f19aca907645 in ./cases/ec3f3f11-75df-4fcc-ba03-f19aca907645/aggregated_data/ec3f3f11-75df-4fcc-ba03-f19aca907645_data.json
# Processing 35620be9-3ba5-4be7-9e00-83103e6a92e6...
# Saved JSON for 35620be9-3ba5-4be7-9e00-83103e6a92e6 in ./cases/35620be9-3ba5-4be7-9e00-83103e6a92e6/aggregated_data/35620be9-3ba5-4be7-9e00-83103e6a92e6_data.json
# Processing ab9cc98a-86ae-4913-bcb2-cc3aeff8abb1...
# Saved JSON for ab9cc98a-86ae-4913-bcb2-cc3aeff8abb1 in ./cases/ab9cc98a-86ae-4913-bcb2-cc3aeff8abb1/aggregated_data/ab9cc98a-86ae-4913-bcb2-cc3aeff8abb1_data.json
# Processing 64bd568d-0509-48fe-8d0a-aef2a85d5c57...
# Saved JSON for 64bd568d-0509-48fe-8d0a-aef2a85d5c57 in ./cases/64bd568d-0509-48fe-8d0a-aef2a85d5c57/aggregated_data/64bd568d-0509-48fe-8d0a-aef2a85d5c57_data.json
# Processing 27d9c162-11bb-48fb-a41a-aa05fcb4c1c2...
# Saved JSON for 27d9c162-11bb-48fb-a41a-aa05fcb4c1c2 in ./cases/27d9c162-11bb-48fb-a41a-aa05fcb4c1c2/aggregated_data/27d9c162-11bb-48fb-a41a-aa05fcb4c1c2_data.json
#                                 case_id patient_id bcr_patient_barcode  \
# 0  b3c267aa-345d-40d8-a8da-f9f08c64f9c7       6923        TCGA-D5-6923
# 2  a85e8208-a6f5-4e91-8f35-ef574f4273fc       6677        TCGA-CM-6677
# 4  835c3e23-ac2b-4bc9-ac65-e3e81adecf77       3941        TCGA-AA-3941
# 6  ea923671-3903-4a79-830d-e7e4b1eabab0       6899        TCGA-AD-6899
# 8  131e0571-de86-415f-b3fb-dc9f971258d3       6932        TCGA-D5-6932
#
#    gender tumor_tissue_site days_to_birth days_to_last_followup days_to_death  \
# 0    MALE             Colon        -21118                    43          None
# 2  FEMALE             Colon        -27575                   153          None
# 4  FEMALE             Colon        -31015                    31          None
# 6    MALE             Colon        -30693                    48          None
# 8    MALE             Colon        -25466                    19          None
#
#                histological_type ajcc_stage_version  ... section_location  \
# 0           Colon Adenocarcinoma                7th  ...           BOTTOM
# 2           Colon Adenocarcinoma                7th  ...           BOTTOM
# 4           Colon Adenocarcinoma                7th  ...           BOTTOM
# 6  Colon Mucinous Adenocarcinoma                7th  ...           BOTTOM
# 8           Colon Adenocarcinoma                7th  ...           BOTTOM
#
#   percent_tumor_cells percent_tumor_nuclei percent_normal_cells  \
# 0                  74                   85                    0
# 2                  70                   60                    0
# 4                  85                   80                    0
# 6                  67                   55                    0
# 8                  65                   80                    0
#
#   percent_necrosis percent_stromal_cells resolution_level embedding  \
# 0                1                    24                3      None
# 2               10                    20                3      None
# 4                5                    10                3      None
# 6                8                    25                3      None
# 8                5                    30                3      None
#
#   event_occured                              dna_methylation_files
# 0             0  0cebad47-0acb-4333-9bf8-e6fb03879c20.methylati...
# 2             0  b423c39b-3c14-4436-b5a6-659899b45deb.methylati...
# 4             0  6738e34d-93e9-4349-88dc-ac141335d7d7.methylati...
# 6             0  c662efa7-aa71-415b-8eb7-58cfdcef403b.methylati...
# 8             0  0e249420-b4fb-438a-b77d-3ffff14c2902.methylati...
#
# [5 rows x 30 columns]
# Consolidated metadata written
